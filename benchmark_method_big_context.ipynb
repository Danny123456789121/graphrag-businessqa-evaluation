# %% [markdown]
# # Imports and load data

# %%
from dotenv import load_dotenv
from rag_utils import setup_rag_embeddings, build_rag_chain
from ragas import SingleTurnSample, EvaluationDataset, evaluate
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from ragas.metrics import Faithfulness, FactualCorrectness
from gen_ai_hub.proxy.langchain.openai import ChatOpenAI
from gen_ai_hub.proxy.core.proxy_clients import get_proxy_client
from langchain_openai import OpenAIEmbeddings

import asyncio
import pandas as pd
import os
import json

load_dotenv(override=True)

model_name = "gpt-4o"
DATA_DIR = "test/"
DATASET = "synthetic_data_big_context_test_citet.json"
proxy_client = get_proxy_client('gen-ai-hub')
llm_sap = ChatOpenAI(proxy_model_name=model_name, proxy_client=proxy_client)
#embeddings_model = OpenAIEmbeddings(proxy_model_name='text-embedding-ada-002', proxy_client=proxy_client)
embeddings_model_own = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
# only for parsing the pdf reports to markdown for the first time
"""
for file in os.listdir(DATA_DIR):
    if file.endswith(".pdf"):
        try:
            print(f"Converting {file} to markdown")
            md_text = LlamaParse(
                result_type="markdown", 
                verbose=True,
                #use_vendor_multimodal_model=True,
                #vendor_multimodal_model_name="openai-gpt-4o-mini",
                #vendor_multimodal_api_key=os.getenv("OPENAI_API_KEY"),
                language="en",
                numWorkers=5).load_data(DATA_DIR + file)
            combined_md_text = "\n\n".join([doc.text for doc in md_text])
            md_file_path = DATA_DIR + file.replace(".pdf", ".md")
            print(f"Saving markdown to {md_file_path}")
            with open(md_file_path, "w", encoding="utf-8") as f:
                f.write(combined_md_text)
            print(f"Successfully converted {file}")
        except Exception as e:
            print(f"Error converting {file}: {e}")
"""

# %% [markdown]
# # RAG

# %%
#setup embeddings and chain
retriever = setup_rag_embeddings(data_dir=DATA_DIR, faiss_path="faiss_big_context", embeddings_model=embeddings_model_own)
rag_chain = build_rag_chain(retriever=retriever, llm=llm_sap)
# Out:
# Loading existing FAISS index from faiss_big_context...
# e:\Repositories\graphrag-businessqa-evaluation\.conda\Lib\site-packages\langsmith\client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# prompt input_variables=['context', 'question'] input_types={} partial_variables={} metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})]

# %% [markdown]
# Map generated questions and ground_truths into evaluation dataset

# %%
with open(DATASET, 'r') as f:
    synthetic_data = json.load(f)

if isinstance(synthetic_data, dict) and 'responses' in synthetic_data:
    synthetic_data = synthetic_data['responses']

queries = [item.get('question', "") for item in synthetic_data]
ground_truths = [item.get('ground_truth', "") for item in synthetic_data]
contexts = [item.get('context', "") for item in synthetic_data]

answers = []
retrieved_contexts = []

for query in queries:
    answer = rag_chain.invoke(query)
    answers.append(answer)
    print("Query: ",query)
    print("Anwer: ",answer)
    retrieved_context = [doc.page_content for doc in retriever.invoke(query)]
    retrieved_contexts.append(retrieved_context)
    print("Retrieved context:",retrieved_context)
# Out:
# Query:  How can SAP leverage its human resource management practices to enhance corporate sustainability and simultaneously boost financial performance in a regional context like Podlaskie Voivodeship?
# Anwer:  SAP can leverage its human resource management practices to enhance corporate sustainability in Podlaskie Voivodeship by implementing sustainable HRM strategies that integrate economic, ecological, and social goals, thus balancing inter-generational needs. This approach can help improve employee recruitment and retention while aligning with regional sustainability priorities, ultimately boosting financial performance. Additionally, focusing on local ecological and ethnic diversity can further tailor these practices to the regional context.
# Retrieved context: ['Sustainable HRM in Polish companies. Additionally, there is a lack of research contribution on the Podlasie region—ecologically and ethnically the most diverse region in the country. While sustainability in environmental terms is evident in the region, the article focuses on sustainability implementation in the business sector. The article helps to close the research gap. Its aim is to examine', '# Keywords\n\nSustainable HRM; corporate sustainability; manager’s opinion; Podlasie enterprises\n\n# 1. Introduction', 'In Poland, the definition of Sustainable HRM was presented by A. Pabian, who claims “the essence of this concept is planning and recruiting employees and affecting them in such a way that they achieve economic, ecological and social goals in the enterprise, thus contributing to balancing inter-generational needs” [26] (pp. 8–9).', 'The issues raised in the research on Sustainable HRM focus on the question of whether the concept of sustainable human resource management is important in achieving sustainable development of an enterprise [32] (p. 91). The results of this study have shown that enterprises in the West Pomeranian Province, Poland, actually use the concept of the sustainable management of human resources in']
# Query:  What role can SAP play in developing green product psychological ownership among its employees to reduce green confusion and enhance environmental performance?
# Anwer:  SAP can play a role in developing green product psychological ownership among its employees by formulating a clear green shared vision and obtaining employee recognition to encourage environmentally friendly behavior. By doing so, SAP can help reduce employee green confusion and enhance the organization’s environmental performance. Strengthening employees’ psychological ownership of green issues is crucial for improving green management performance.
# Retrieved context: ['# Keywords\n\ngreen shared vision; psychological ownership theory; green product psychological ownership; employee green confusion; employee environmental performance\n\n# 1. Introduction', 'products and services as well as the characteristics of its environmental policy during information processing. Therefore, companies must formulate a clear green common vision and effectively obtain employee recognition to encourage the green behavior and performance of employees [24, 34, 35]. GSV can encourage the green behavior and performance of employees, effectively develop employee', 'Given the aforementioned information, employees play an important role when designing sustainable development strategies for an enterprise. The occurrence of employee green confusion (EGC) cannot be ruled out when employees promote green shared vision (GSV). However, studies on green confusion have not focused on the views of an enterprise’s employees. Most of these studies have examined consumer', 'psychological ownership. The overall process of an enterprise to effectively strengthen employees’ mentality of green issues is an important key to improving the organization’s green management performance. In the process of improving EEP, companies must not only strengthen the psychological process of employees’ green issues, but reducing EGC is also an important key. Effectively reducing EGC']
# Query:  In what ways can SAP's corporate sustainability practices be tailored to align with the financial perceptions and expectations of Chinese stakeholders, especially in relation to the GRI Sustainability Reporting Guidelines?
# Anwer:  To align SAP's corporate sustainability practices with Chinese stakeholders' financial perceptions, SAP should consider adapting the GRI Sustainability Reporting Guidelines to reflect Chinese-specific concerns and government priorities in sustainability. They should emphasize indicators that resonate with Chinese national sustainability goals and address differences from Western contexts. Understanding the unique perceptions of financial analysts in China can guide SAP in tailoring its sustainability strategies effectively.
# Retrieved context: ['In China, the GRI (2013) guidelines are used as the basis of most sustainability reportings. In recent decades, GRI has attempted to provide comprehensive guidelines for CSD by setting indicators in corporate economic, environmental and social sustainability (Chauvey et al., 2015). Firms that adopt GRI Sustainability Reporting Guidelines need to report their strategy in the company profiles,', 'and political influences for being sustainably orientated can be significantly different between countries. This study aims to examine the perception of financial analysts, as CSD report users, in China about the level of importance of various indicators of corporate sustainability described in the Global Reporting Initiative (GRI) Sustainability Reporting Guidelines.', 'relevance to existing research into China’s corporate sustainability or social responsibility practices and reporting mechanisms. We found that the Chinese concerns on corporate sustainability are partially different from the Western context-based literature, as well as that from the GRI. The national pursuit of sustainability development engaged by the government has an inevitable influence to', 'Originality/value – This study addresses the need for differing corporate sustainability guidelines for different nations and cultures, specifically within the Chinese context. It also contributes to the corporate sustainability literature by adding to our understanding of how financial analysts in China, as CSD report users, perceive aspects of sustainability.']
# Query:  How can SAP address the challenges of high ownership concentration impacting corporate sustainability performance in emerging markets like Brazil?
# Anwer:  SAP can address the challenges of high ownership concentration impacting corporate sustainability performance in emerging markets like Brazil by encouraging diversified ownership structures. This would enhance public firm accountability and stakeholder pressure for better sustainability practices. Additionally, integrating corporate governance strategies that prioritize shareholder interests and sustainability can help mitigate the negative effects of ownership concentration.
# Retrieved context: ['The present work offers insights on the determinants of firm’s social and sustainability policies in an important emerging market (Brazil). The research builds on stakeholder and agency theories by investigating the possible effect of industry environmental risk and ownership concentration on CSP as proxied by firm’s membership to the Brazilian firm ISE. The study contributes to the literature', 'This research aims to analyze firm’s attributes that are related to social and sustainability policies of Brazilian firms, focusing on firm’s environmental risk and ownership concentration. In this regard, more recently, ownership structure has been suggested to play a role on firm’s social and sustainability policies because of distinct shareholders’ interests and the diversity in institutional', 'Sustainability indices, as is the case of ISE in Brazil, have corporate governance as a very relevant component as mentioned above (Section 2.2). In this context, high ownership concentration may also be negative to public firm accountability that tends to improve with a decrease in ownership concentration and more shareholders pressuring for better firm accountability in the opposite direction', 'Purpose – Over the past two decades, there has been an increasing interest on corporate social responsibility by a number of constituencies – corporate managers, research scholars, policymakers and investors. In this context, corporate sustainability performance (CSP) has been a central focus of attention. This paper aims to analyze CSP determinants in Brazil, an important emerging market. Firm']
# Query:  What strategies can SAP adopt to ensure that its sustainability initiatives lead to tangible financial benefits, particularly in highly regulated sectors like banking in Bangladesh?
# Anwer:  SAP can ensure its sustainability initiatives lead to financial benefits by aligning with regulatory guidelines that promote sustainability, such as the ERM guidelines in Bangladesh, which can lead to lower-cost capital provisions. Additionally, SAP should focus on stakeholder engagement and community building to enhance legitimacy and drive positive financial outcomes. By leveraging institutional pressure and aligning with both environmental and financial performance goals, SAP can achieve tangible financial benefits in highly regulated sectors.
# Retrieved context: ['performance [18]. Despite some research on sustainability in Bangladeshi banks, the question remains whether regulatory sustainability guidelines improve both the environmental and financial performance of the regulated banks.', 'The institutional pressure conducted through the ERM guidelines drives Bangladeshi banks to become more sustainable. They want to take the opportunity of the lower-cost capital provision by Bangladesh Bank and wish to avoid the adverse effects on their legitimacy of not reacting to the.\n\n# Sustainability 2020, 12, 7999', 'Concerning organizational ethics and sustainability in South Asia, the results suggest that regulatorily induced sustainability activities have a positive effect on Bangladeshi banks. Some studies in other world regions came to similar conclusions, for instance, in China [7, 86], but also in North America and Europe [87]. The missing connection between financial performance and sustainability', 'The latter includes stakeholder engagement, community building, social inclusion, and so on. These issues should be at the core of sustainable banking in Bangladesh and other South Asian countries. However, an earlier study by Khan and Islam [13] suggests a similar result. Hence, it looks like there has not been much change in addressing social sustainability issues. As expected, the Bangladesh']

# %%
# populate eval dataset

evaluation_samples = []

for query, answer, retrieved_context, ground_truth in zip(queries, answers, retrieved_contexts, ground_truths):
    sample = SingleTurnSample(
        user_input=query,
        response=answer,
        reference=ground_truth,
        retrieved_contexts=retrieved_context
    )
    evaluation_samples.append(sample)

evaluation_dataset = EvaluationDataset(samples=evaluation_samples)

# %%
print(evaluation_dataset.samples)
print(type(evaluation_dataset.samples))
print(type(evaluation_dataset.samples[0]))
print(dir(evaluation_dataset.samples[0]))
# Out:
# [SingleTurnSample(user_input='How can SAP leverage its human resource management practices to enhance corporate sustainability and simultaneously boost financial performance in a regional context like Podlaskie Voivodeship?', retrieved_contexts=['Sustainable HRM in Polish companies. Additionally, there is a lack of research contribution on the Podlasie region—ecologically and ethnically the most diverse region in the country. While sustainability in environmental terms is evident in the region, the article focuses on sustainability implementation in the business sector. The article helps to close the research gap. Its aim is to examine', '# Keywords\n\nSustainable HRM; corporate sustainability; manager’s opinion; Podlasie enterprises\n\n# 1. Introduction', 'In Poland, the definition of Sustainable HRM was presented by A. Pabian, who claims “the essence of this concept is planning and recruiting employees and affecting them in such a way that they achieve economic, ecological and social goals in the enterprise, thus contributing to balancing inter-generational needs” [26] (pp. 8–9).', 'The issues raised in the research on Sustainable HRM focus on the question of whether the concept of sustainable human resource management is important in achieving sustainable development of an enterprise [32] (p. 91). The results of this study have shown that enterprises in the West Pomeranian Province, Poland, actually use the concept of the sustainable management of human resources in'], reference_contexts=None, response='SAP can leverage its human resource management practices to enhance corporate sustainability in Podlaskie Voivodeship by implementing sustainable HRM strategies that integrate economic, ecological, and social goals, thus balancing inter-generational needs. This approach can help improve employee recruitment and retention while aligning with regional sustainability priorities, ultimately boosting financial performance. Additionally, focusing on local ecological and ethnic diversity can further tailor these practices to the regional context.', multi_responses=None, reference="SAP can leverage its HRM practices by implementing a Sustainable HRM framework that focuses on ecological, social, and strategic aspects. By promoting pro-environmental behaviors, enhancing diversity management, and supporting work-life balance, SAP can create a sustainable organizational culture. This approach not only enhances corporate sustainability by aligning with regional ecological standards but also boosts financial performance through improved employee engagement and reduced turnover. In Podlaskie Voivodeship, where the natural environment is a priority, aligning HRM practices with local sustainability values can further enhance SAP's reputation and stakeholder relationships, leading to better financial outcomes.", rubrics=None), SingleTurnSample(user_input='What role can SAP play in developing green product psychological ownership among its employees to reduce green confusion and enhance environmental performance?', retrieved_contexts=['# Keywords\n\ngreen shared vision; psychological ownership theory; green product psychological ownership; employee green confusion; employee environmental performance\n\n# 1. Introduction', 'products and services as well as the characteristics of its environmental policy during information processing. Therefore, companies must formulate a clear green common vision and effectively obtain employee recognition to encourage the green behavior and performance of employees [24, 34, 35]. GSV can encourage the green behavior and performance of employees, effectively develop employee', 'Given the aforementioned information, employees play an important role when designing sustainable development strategies for an enterprise. The occurrence of employee green confusion (EGC) cannot be ruled out when employees promote green shared vision (GSV). However, studies on green confusion have not focused on the views of an enterpris ...
# <class 'list'>
# <class 'ragas.dataset_schema.SingleTurnSample'>
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__repr__', '__repr_args__', '__repr_name__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_check_frozen', '_copy_and_set_values', '_get_value', '_iter', 'construct', 'copy', 'dict', 'from_orm', 'get_features', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'multi_responses', 'parse_file', 'parse_obj', 'parse_raw', 'reference', 'reference_contexts', 'response', 'retrieved_contexts', 'rubrics', 'schema', 'schema_json', 'to_dict', 'to_string', 'update_forward_refs', 'user_input', 'validate']

# %%
evaluator_llm = LangchainLLMWrapper(llm_sap)
evaluator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

metrics = [
    FactualCorrectness(llm=evaluator_llm, mode="precision", name="FactualCorrectness_Precision"),
    FactualCorrectness(llm=evaluator_llm, mode="recall", name="FactualCorrectness_Recall"),
    FactualCorrectness(llm=evaluator_llm, mode="f1", name="FactualCorrectness_F1"),
    #FactualCorrectnessAllMetrics(llm=evaluator_llm, name="FactualCorrectness_All"),
    Faithfulness(llm=evaluator_llm), 
 
]
results = evaluate(dataset=evaluation_dataset, metrics=metrics)
df_rag = results.to_pandas()

# factual_correctness = df['FactualCorrectness_All'].apply(pd.Series)
# df = pd.concat([df.drop(['FactualCorrectness_All'], axis=1), factual_correctness], axis=1)

# print(df[['FactualCorrectness_Precision', 'FactualCorrectness_Recall', 'FactualCorrectness_F1', 'Faithfulness']])
# Out:
# Evaluating: 100%|██████████| 20/20 [00:38<00:00,  1.93s/it]

# %% [markdown]
# # Results

# %%
pd.set_option('display.max_colwidth', 200) # default is 50 / None for unlimited

df_rag

# context recall = measures how many of the relevant documents (or pieces of information) were successfully retrieved
# factual correctness (precision) = proportion of correct claims made that also found in the reference / how many are correct 
# factual correctness (recall) = proportion of facts in the reference that are also present in the response / how many are found
# faithfulness = are the claims made in the response supported by the retrieved context
# semantic similarity = how similar the response is to the ground truth
# Out:
#                                                                                                                                                                                                 user_input  \
# 0        How can SAP leverage its human resource management practices to enhance corporate sustainability and simultaneously boost financial performance in a regional context like Podlaskie Voivodeship?
# 1                                          What role can SAP play in developing green product psychological ownership among its employees to reduce green confusion and enhance environmental performance?
# 2  In what ways can SAP's corporate sustainability practices be tailored to align with the financial perceptions and expectations of Chinese stakeholders, especially in relation to the GRI Sustainabi...
# 3                                                       How can SAP address the challenges of high ownership concentration impacting corporate sustainability performance in emerging markets like Brazil?
# 4                    What strategies can SAP adopt to ensure that its sustainability initiatives lead to tangible financial benefits, particularly in highly regulated sectors like banking in Bangladesh?
#
#                                                                                                                                                                                         retrieved_contexts  \
# 0  [Sustainable HRM in Polish companies. Additionally, there is a lack of research contribution on the Podlasie region—ecologically and ethnically the most diverse region in the country. While sustai...
# 1  [# Keywords\n\ngreen shared vision; psychological ownership theory; green product psychological ownership; employee green confusion; employee environmental performance\n\n# 1. Introduction, produc...
# 2  [In China, the GRI (2013) guidelines are used as the basis of most sustainability reportings. In recent decades, GRI has attempted to provide comprehensive guidelines for CSD by setting indicators...
# 3  [The present work offers insights on the determinants of firm’s social and sustainability policies in an important emerging market (Brazil). The research builds on stakeholder and agency theories ...
# 4  [performance [18]. Despite some research on sustainability in Bangladeshi banks, the question remains whether regulatory sustainability guidelines improve both the environmental and financial perf...
#
#                                                                                                                                                                                                   response  \
# 0  SAP can leverage its human resource management practices to enhance corporate sustainability in Podlaskie Voivodeship by implementing sustainable HRM strategies that integrate economic, ecological...
# 1  SAP can play a role in developing green product psychological ownership among its employees by formulating a clear green shared vision and obtaining employee recognition to encourage environmental...
# 2  To align SAP's corporate sustainability practices with Chinese stakeholders' financial perceptions, SAP should consider adapting the GRI Sustainability Reporting Guidelines to reflect Chinese-spec...
# 3  SAP can address the challenges of high ownership concentration impacting corporate sustainability performance in emerging markets like Brazil by encouraging diversified ownership structures. This ...
# 4  SAP can ensure its sustainability initiatives lead to financial benefits by aligning with regulatory guidelines that promote sustainability, such as the ERM guidelines in Bangladesh, which can lea...
#
#                                                                                                                                                                                                  reference  \
# 0  SAP can leverage its HRM practices by implementing a Sustainable HRM framework that focuses on ecological, social, and strategic aspects. By promoting pro-environmental behaviors, enhancing divers...
# 1  SAP can play a pivotal role in developing green product psychological ownership by fostering a shared green vision and providing training that emphasizes the importance of sustainability in produc...
# 2  To align SAP's corporate sustainability practices with Chinese stakeholders' financial perceptions, SAP should focus on enhancing the environmental and social aspects of its sustainability reports...
# 3  In emerging markets like Brazil, high ownership concentration can negatively impact corporate sustainability performance by prioritizing short-term gains over long-term sustainability goals. SAP c...
# 4  SAP can adopt strategies such as integrating sustainability criteria into financial decision-making processes and developing products that meet regulatory requirements while promoting environmenta...
#
#    FactualCorrectness_Precision  FactualCorrectness_Recall  \
# 0                          0.57                       0.33
# 1                          0.67                       0.50
# 2                          0.80                       0.50
# 3                          0.40                       0.25
# 4                          0.12                       0.17
#
#    FactualCorrectness_F1  faithfulness
# 0                   0.53         0.000
# 1                   0.57         0.375
# 2                   0.50         0.250
# 3                   0.31         0.625
# 4                   0.24         0.100

# %%
average_metrics = df_rag[['FactualCorrectness_Precision', 'FactualCorrectness_Recall', 'FactualCorrectness_F1']].mean().round(4)

print("Average for each metric:")
print(average_metrics)
# Out:
# Average for each metric:
# FactualCorrectness_Precision    0.512
# FactualCorrectness_Recall       0.350
# FactualCorrectness_F1           0.430
# dtype: float64

# %% [markdown]
# # GraphRAG

# %% [markdown]
# ## Indexing

# %%
# graphrag initial setup
# !mkdir ./graphrag_big_context
# !mkdir ./input_big_context
# !python -m graphrag init --root ./graphrag_big_context
# Out:
# The syntax of the command is incorrect.
# ⠋ GraphRAG Indexer
# Initializing project at
# E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context
# ⠋ GraphRAG Indexer

# %%
# indexing, only run once unless you want to update the index
# !python -m graphrag index --root ./graphrag_big_context
# Out:
# ⠋ GraphRAG Indexer
# Logging enabled at
# E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context\logs\indexi
# ng-engine.log
# ⠋ GraphRAG Indexer
# ⠋ GraphRAG Indexer
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# 🚀 create_base_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# Empty DataFrame
# Columns: []
# Index: []
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# └── create_base_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_final_documents
# 🚀 create_final_documents
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_final_documents
#                                  id  ...
# text_unit_ids
# 0  5bb3d56fa17e8664e38f5cc8d907b00f  ...  [a02cec7bdb3392713686e38571f1cc57,
# 3e423af2923...
# 1  b77919e2f131e709c5cc636e2b47b771  ...  [80938d0723df60021055b0e9f9edbb9b,
# 0fe1ec60bf9...
# 2  7c91fc19b40986c5bc4b08f448b26db4  ...  [449179fdb667f9e3bc81fcc1fa0a488c,
# 132ac03d78d...
# 3  8f9a88e83d98bad6e9994f3dce22ab04  ...  [8a99caa1c4fd5453df8839cfa6d438e6,
# 16e2227f935...
# 4  a0b217c21520150d30bbf7c3ec8b534e  ...  [664ad96323e36ad75a08801557c63d6c,
# 91f17e21111...
# 5  cb01cca42f119560329f266f012d4f3f  ...  [6d55990560307e913396e6cd088bc868,
# 58b8017a90e...
#
# [6 rows x 5 columns]
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_final_documents
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:01
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:02
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:03
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:04
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:05
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:06
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:07
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:08
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:09
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:10
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:11
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:12
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:13
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:14
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:15
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:16
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:17
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:18
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:19
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:20
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:21
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% -:--:-- 0:00:22
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% -:--:-- 0:00:22
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% -:--:-- 0:00:23
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   2% 0:03:11 0:00:24
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   2% 0:03:11 0:00:24
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   3% 0:02:21 0:00:25
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   4% 0:01:37 0:00:25
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   4% 0:01:37 0:00:26
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   5% 0:01:24 0:00:26
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   5% 0:01:24 0:00:27
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:01:22 0:00:27
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:01:13 0:00:27
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:01:06 0:00:27
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:00:59 0:00:27
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:00:59 0:00:28
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:00:59 0:00:29
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:01:10 0:00:29
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:01:10 0:00:30
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:01:10 0:00:31
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:01:10 0:00:32
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:01:10 0:00:33
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:01:34 0:00:33
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:01:20 0:00:33
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  14% 0:01:16 0:00:34
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  14% 0:01:16 0:00:34
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  15% 0:01:11 0:00:34
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  16% 0:01:07 0:00:34
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  16% 0:01:07 0:00:35
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  17% 0:01:07 0:00:35
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  17% 0:01:07 0:00:36
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  17% 0:01:07 0:00:37
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  18% 0:01:11 0:00:37
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  19% 0:01:08 0:00:37
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  20% 0:01:04 0:00:37
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  20% 0:01:04 0:00:38
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  20% 0:01:04 0:00:39
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  20% 0:01:04 0:00:40
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  21% 0:01:14 0:00:41
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  22% 0:01:10 0:00:41
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  22% 0:01:10 0:00:42
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  23% 0:01:10 0:00:42
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  23% 0:01:10 0:00:43
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  24% 0:01:11 0:00:43
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  24% 0:01:11 0:00:44
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  25% 0:01:09 0:00:44
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---- ---------------  25% 0:01:09 0:00:45
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  25% 0:01:10 0:00:45
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  26% 0:01:06 0:00:46
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  27% 0:01:05 0:00:46
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  27% 0:01:05 0:00:47
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  28% 0:01:05 0:00:47
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  29% 0:01:02 0:00:47
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  29% 0:01:02 0:00:48
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  29% 0:01:02 0:00:49
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  29% 0:01:02 0:00:50
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----- --------------  29% 0:01:02 0:00:51
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  30% 0:01:09 0:00:51
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  30% 0:01:09 0:00:52
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  30% 0:01:09 0:00:53
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  30% 0:01:09 0:00:54
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  30% 0:01:09 0:00:55
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  31% 0:01:17 0:00:55
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  31% 0:01:17 0:00:56
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  31% 0:01:17 0:00:57
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  31% 0:01:17 0:00:58
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  32% 0:01:29 0:00:59
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  32% 0:01:29 0:00:59
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  32% 0:01:29 0:01:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  33% 0:01:21 0:01:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  33% 0:01:21 0:01:01
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  34% 0:01:22 0:01:02
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  34% 0:01:22 0:01:02
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  34% 0:01:22 0:01:03
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  34% 0:01:22 0:01:04
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------ -------------  34% 0:01:22 0:01:05
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  35% 0:01:47 0:01:06
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  35% 0:01:47 0:01:06
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  35% 0:01:47 0:01:07
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  35% 0:01:47 0:01:08
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  35% 0:01:47 0:01:09
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  35% 0:01:47 0:01:10
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  35% 0:01:47 0:01:11
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  36% 0:02:24 0:01:12
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  36% 0:02:24 0:01:12
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:12
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:13
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:14
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:15
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:16
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:17
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:18
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:19
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:20
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:21
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:22
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:23
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:24
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:25
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:26
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:27
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  37% 0:02:14 0:01:28
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  38% 0:05:12 0:01:29
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ------- ------------  39% 0:04:25 0:01:29
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  40% 0:04:14 0:01:29
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  40% 0:04:14 0:01:29
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  40% 0:04:14 0:01:30
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  41% 0:04:06 0:01:30
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  41% 0:04:06 0:01:31
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  41% 0:04:06 0:01:32
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  41% 0:04:06 0:01:33
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  41% 0:04:06 0:01:34
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  42% 0:04:09 0:01:35
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  43% 0:03:35 0:01:35
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  44% 0:02:54 0:01:36
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  44% 0:02:54 0:01:36
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  44% 0:02:54 0:01:37
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  44% 0:02:54 0:01:38
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  44% 0:02:54 0:01:39
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -------- -----------  44% 0:02:54 0:01:40
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  45% 0:03:04 0:01:41
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  45% 0:03:04 0:01:41
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  46% 0:03:03 0:01:42
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  46% 0:03:03 0:01:42
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  47% 0:01:24 0:01:43
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  48% 0:01:16 0:01:43
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  48% 0:01:16 0:01:43
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  48% 0:01:16 0:01:45
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  49% 0:01:20 0:01:45
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------- ----------  49% 0:01:20 0:01:46
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  50% 0:01:13 0:01:46
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  50% 0:01:13 0:01:47
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  51% 0:01:10 0:01:47
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  51% 0:01:10 0:01:48
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  51% 0:01:10 0:01:49
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  51% 0:01:10 0:01:50
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  51% 0:01:10 0:01:51
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  52% 0:01:20 0:01:51
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  53% 0:01:13 0:01:52
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  53% 0:01:13 0:01:53
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  54% 0:01:11 0:01:53
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  54% 0:01:11 0:01:54
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ---------- ---------  55% 0:01:09 0:01:54
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----------- --------  56% 0:01:04 0:01:54
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----------- --------  57% 0:01:00 0:01:54
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----------- --------  57% 0:01:00 0:01:55
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----------- --------  57% 0:01:00 0:01:56
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----------- --------  58% 0:01:01 0:01:57
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph ----------- --------  58% 0:01:01 0:01:57
# ⠼ GraphRAG Indexer
# ...
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# [2024-12-11T00:11:00Z WARN  lance::dataset] No existing dataset at E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context\output\lancedb\default-community-full_content.lance, it will be created
# [2024-12-11T00:11:03Z WARN  lance::dataset] No existing dataset at E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context\output\lancedb\default-text_unit-text.lance, it will be created
# [2024-12-11T00:11:07Z WARN  lance::dataset] No existing dataset at E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context\output\lancedb\default-entity-description.lance, it will be created
# └── generate_text_embeddings
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# 🚀 generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# Empty DataFrame
# Columns: []
# Index: []
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 6 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# 🚀 All workflows completed successfully.

# %% [markdown]
# ## Query Engine

# %% [markdown]
# ### Global Search
#
# follows the implementations guide by the docs https://microsoft.github.io/graphrag/examples_notebooks/global_search/

# %%
from graphrag_utils import setup_graphrag
import pandas as pd
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.typing import OpenaiApiType
import os
import json
import asyncio

api_key = os.environ["GRAPHRAG_API_KEY"]


llm = ChatOpenAI(
    api_key=api_key,
    model="gpt-4o-mini",
    api_type=OpenaiApiType.OpenAI,
    max_retries=20,
)
community_level = 2

with open(DATASET, 'r') as file:
    data = json.load(file)
    
queries = [response['question'] for response in data['responses']]
references = [response['ground_truth'] for response in data['responses']]

async def perform_global_search(query):
    print(f"Performing search with query: {query}")
    result = await search_engine_global.asearch(query)
    print(f"Result for query: {query} is: {result.response}")
    return result.response

tasks = [perform_global_search(query) for query in queries]
results = await asyncio.gather(*tasks)

evaluation_samples = []
for query, result, reference in zip(queries, results, references):
    sample = SingleTurnSample(
        user_input=query,
        response=result,
        reference=reference
    )
    evaluation_samples.append(sample)

evaluation_dataset = EvaluationDataset(samples=evaluation_samples)
#print(evaluation_dataset)
# Out:
# Performing search with query: How can SAP leverage its human resource management practices to enhance corporate sustainability and simultaneously boost financial performance in a regional context like Podlaskie Voivodeship?
# Performing search with query: What role can SAP play in developing green product psychological ownership among its employees to reduce green confusion and enhance environmental performance?
# Performing search with query: In what ways can SAP's corporate sustainability practices be tailored to align with the financial perceptions and expectations of Chinese stakeholders, especially in relation to the GRI Sustainability Reporting Guidelines?
# Performing search with query: How can SAP address the challenges of high ownership concentration impacting corporate sustainability performance in emerging markets like Brazil?
# Performing search with query: What strategies can SAP adopt to ensure that its sustainability initiatives lead to tangible financial benefits, particularly in highly regulated sectors like banking in Bangladesh?
# Result for query: What role can SAP play in developing green product psychological ownership among its employees to reduce green confusion and enhance environmental performance? is: ## Enhancing Green Product Psychological Ownership at SAP
#
# SAP can play a pivotal role in developing green product psychological ownership among its employees, which is essential for reducing green confusion and enhancing overall environmental performance. This can be achieved through several strategic initiatives that align with the company's sustainability goals.
#
# ### Integration of Sustainability into Corporate Culture
#
# One of the primary strategies SAP may adopt is the integration of sustainability into its core values and practices. By fostering a culture that emphasizes green initiatives, SAP can encourage employees to take personal responsibility for environmental outcomes. This approach may reduce green confusion and enhance overall environmental performance by instilling a sense of ownership over sustainability efforts [Data: Reports (69, 167, 221, 79, 119)].
#
# ### Training and Education Programs
#
# Implementing comprehensive training programs focused on sustainability and green product development is crucial. Such programs will enhance employees' understanding of the company's environmental goals and clarify their roles in achieving these objectives. By reducing misconceptions about sustainability initiatives, SAP can empower employees to engage more actively in environmental practices [Data: Reports (203, 106, 75)].
#
# ### Fostering Green Shared Values
#
# SAP can also promote Green Shared Values (GSV) within its organizational culture. By cultivating a shared vision of sustainability, the company may enhance employee engagement and performance in environmental initiatives. This shared commitment can significantly reduce green confusion and align individual actions with corporate sustainability objectives [Data: Reports (1, 7, 118, 80, 107, +more)].
#
# ### Green Human Resource Management Practices
#
# Integrating Green Human Resource Management (Green HRM) practices into the company's HR strategies will further support the development of psychological ownership among employees. By embedding environmental management into HR practices, SAP can encourage employees to take responsibility for sustainability initiatives, thereby enhancing their commitment to green products and reducing confusion [Data: Reports (116, 442, 701, 738, +more)].
#
# ### Communication and Recognition
#
# Effective communication regarding sustainability goals and the significance of individual contributions is essential. SAP should establish clear communication channels to inform employees about environmental initiatives and their roles within them. Additionally, recognition programs that reward employees for their contributions to sustainability can enhance psychological ownership and motivate further engagement in green practices [Data: Reports (167, 221, 79, 119)].
#
# ### Leveraging Technology and Data Analytics
#
# Utilizing technological capabilities and data analytics can provide employees with insights into the impact of their actions on environmental performance. By tracking and reporting on sustainability metrics, SAP can foster a sense of accountability and ownership among employees, further reducing green confusion and promoting sustainable practices [Data: Reports (221, 79, 119, 128, 57)].
#
# ### Conclusion
#
# In summary, SAP has the potential to significantly enhance green product psychological ownership among its employees through a multifaceted approach that includes cultural integration, training, shared values, HR practices, effective communication, and the use of technology. By implementing these strategies, SAP may not only reduce green confusion but also improve its overall environmental performance, aligning employee actions with the company's sustainability objectives.
# Result for query: How can SAP address the challenges of high ownership concentration impacting corporate sustainability performance in emerging markets like Brazil? is: ## Addressing High Ownership Concentration in Corporate Sustainability
#
# High ownership concentration in emerging markets, particularly in Brazil, presents significant challenges for corporate sustainability performance. Companies with concentrated ownership structures may prioritize short-term financial gains over long-term sustainability goals, leading to governance issues and agency conflicts. To effectively address these challenges, SAP can implement a multifaceted approach that leverages its expertise in corporate governance, sustainability management, and stakeholder engagement.
#
# ### Enhancing Governance Practices
#
# One of the primary strategies SAP may employ is to enhance corporate governance frameworks within organizations facing high ownership concentration. By promoting transparency and accountability, SAP can help firms establish balanced ownership structures that mitigate agency conflicts. This approach is essential for ensuring that sustainability practices are integrated into decision-making processes, allowing companies to align their operations with broader societal and environmental responsibilities [Data: Reports (159, 152, 236)].
#
# ### Integrating Sustainability into Business Operations
#
# SAP can also assist organizations in Brazil by integrating sustainability principles into their core business operations. This involves developing tailored solutions that facilitate the incorporation of sustainability metrics into corporate governance systems. By doing so, firms can better navigate the complexities of ownership concentration while improving their sustainability performance [Data: Reports (105, 217, 230, 61, 55)]. Furthermore, SAP may implement sustainability management systems that align corporate governance with sustainability practices, ensuring that decision-makers prioritize long-term sustainability goals [Data: Reports (50, 14)].
#
# ### Promoting Stakeholder Engagement
#
# Effective stakeholder engagement is crucial in environments with high ownership concentration. SAP can facilitate better communication and collaboration among diverse stakeholders, including minority shareholders, to ensure that their interests are represented in corporate decision-making. This collaborative approach can help mitigate the risks associated with concentrated ownership and promote more sustainable corporate practices [Data: Reports (220, 172, 77, 169, 192)]. By fostering an inclusive environment, SAP can assist companies in aligning their sustainability strategies with societal expectations, thereby enhancing corporate reputation and performance [Data: Reports (203)].
#
# ### Providing Training and Resources
#
# To empower organizations in Brazil, SAP may also focus on providing training and resources related to corporate social responsibility (CSR) and sustainable practices. This education can help shift the mindset of controlling shareholders towards recognizing the value of sustainable practices, ultimately improving corporate sustainability performance [Data: Reports (130, 171, 204, 240, 154)]. Additionally, SAP can advocate for the adoption of sustainability reporting frameworks that enhance transparency and accountability, further supporting firms in demonstrating their commitment to sustainability [Data: Reports (163, 98, 148)].
#
# ### Leveraging Technology for Data Management
#
# SAP's technology solutions can play a pivotal role in enhancing data management and analytics related to sustainability performance. By providing tools that enable companies to track and report on their sustainability metrics effectively, SAP can facilitate better decision-making and encourage organizations to adopt more responsible practices, even in environments with high ownership concentration [Data: Reports (130, 171, 204, 240, 154)]. This data-driven approach will empower firms to make informed decisions that align with sustainable development goals.
#
# ### Conclusion
#
# In summary, SAP can address the challenges posed by high ownership concentration in Brazil by enhancing governance practices, integrating sustainability into business operations, promoting stakeholder engagement, providing training and resources, and leveraging technology for better data management. By implementing these strategies, SAP shall enable organizations to navigate the complexities of ownership concentration while fostering a culture of sustainability that benefits both the companies and the broader society [Data: Reports (126, 232, +more)].
# Result for query: How can SAP leverage its human resource management practices to enhance corporate sustainability and simultaneously boost financial performance in a regional context like Podlaskie Voivodeship? is: ## Enhancing Corporate Sustainability through HRM Practices
#
# SAP can significantly enhance its corporate sustainability and financial performance in the Podlaskie Voivodeship by integrating sustainable human resource management (HRM) practices into its operations. This approach not only aligns with the region's commitment to sustainable development but also positions SAP as a leader in corporate responsibility.
#
# ### Integration of Sustainable HRM Practices
#
# 1. **Diversity Management**: By fostering an inclusive workplace culture through diversity management, SAP can enhance employee satisfaction and engagement. This commitment to diversity is essential for creating an environment that values different perspectives, which can lead to innovative solutions for sustainability challenges [Data: Reports (119)].
#
# 2. **Sustainable HRM Strategies**: Implementing sustainable HRM practices that balance economic, social, and environmental goals will be crucial. This alignment can improve employee well-being and organizational performance, ultimately contributing to corporate sustainability while enhancing financial outcomes [Data: Reports (118, 80, 107, 195, 141)].
#
# 3. **Employee Engagement in Sustainability Initiatives**: Engaging employees in sustainability initiatives through training programs can cultivate a culture of sustainability awareness. This investment in human capital not only equips employees with the necessary skills but also enhances their commitment to sustainable practices, leading to improved operational efficiency and financial performance [Data: Reports (240, 228, 187, 204, 171, +more)].
#
# ### Fostering a Culture of Sustainability
#
# 1. **Sustainability Metrics in Performance Evaluations**: Integrating sustainability metrics into employee performance evaluations will encourage staff to prioritize sustainable practices in their daily operations. This alignment of individual performance with corporate sustainability objectives can enhance overall performance and profitability [Data: Reports (125, 28, 158, 67, 200, +more)].
#
# 2. **Training and Development Programs**: SAP should implement training programs focused on sustainability to equip its workforce with the skills needed to contribute effectively to sustainability goals. This approach not only enhances employee capabilities but also fosters innovation and efficiency, which are essential for maintaining competitiveness in the region [Data: Reports (116, 452, 738, +more)].
#
# 3. **Collaboration with Local Institutions**: Collaborating with local educational institutions can help SAP develop tailored HRM strategies that address regional sustainability challenges. Such partnerships can create a talent pool well-versed in sustainable practices, enhancing SAP's competitive advantage while contributing to local economic development [Data: Reports (240, 228, 187, 204, 171, +more)].
#
# ### Financial Performance and Corporate Reputation
#
# 1. **Cost Reductions through Efficient Resource Management**: By adopting sustainable HRM practices, SAP may achieve cost reductions associated with efficient resource management. Engaging employees in sustainability efforts can lead to innovation and operational efficiencies, which are essential for maintaining competitiveness in the Podlaskie Voivodeship's economic landscape [Data: Reports (75, 120, 81)].
#
# 2. **Attracting Sustainability-Oriented Talent**: A focus on sustainability within HRM practices can attract talent that values corporate responsibility. This not only enhances SAP's reputation but also positions the company to respond effectively to sustainability challenges, ultimately leading to better financial performance [Data: Reports (115)].
#
# 3. **Building Stakeholder Trust**: By promoting transparency and accountability in sustainability reporting, SAP can build trust with stakeholders and investors. This trust may lead to increased investment and improved financial performance in the region [Data: Reports (159, 85, 54, +more)].
#
# ### Conclusion
#
# In summary, SAP can leverage its human resource management practices to enhance corporate sustainability and boost financial performance in the Podlaskie Voivodeship by integrating sustainable HRM strategies, fostering a culture of sustainability, and collaborating with local institutions. This multifaceted approach will not only align with regional sustainability goals but also position SAP as a leader in corporate responsibility, ultimately benefiting both the organization and the community it serves.
# Result for query: What strategies can SAP adopt to ensure that its sustainability initiatives lead to tangible financial benefits, particularly in highly regulated sectors like banking in Bangladesh? is: ## Strategies for SAP to Enhance Financial Benefits from Sustainability Initiatives
#
# SAP can adopt several strategic approaches to ensure that its sustainability initiatives yield tangible financial benefits, especially in the highly regulated banking sector in Bangladesh. These strategies focus on integrating sustainability into core business practices, aligning with regulatory requirements, and leveraging technology and partnerships.
#
# ### 1. Integration of Sustainability and Financial Performance
#
# SAP should prioritize the integration of sustainability performance metrics with financial performance assessments. Research indicates that higher sustainability performance is often linked to improved financial outcomes in the banking sector. By demonstrating the financial benefits of sustainability initiatives, SAP can position these efforts as strategic financial decisions rather than mere ethical imperatives [Data: Reports (105)].
#
# ### 2. Tailored Solutions for Regulatory Compliance
#
# Developing tailored sustainability solutions that align with the specific regulatory requirements of the banking sector in Bangladesh is crucial. This approach not only ensures compliance but also enhances operational efficiency, potentially leading to reduced costs associated with regulatory penalties [Data: Reports (99, 221, 22, 134, 211)]. By understanding local market conditions and regulations, SAP can create value-added services that help banks navigate compliance challenges while improving their sustainability performance [Data: Reports (209, 187, 204, 240, 171, +more)].
#
# ### 3. Corporate Social Responsibility (CSR) Reporting
#
# Implementing robust CSR reporting practices can help SAP demonstrate its commitment to sustainability, which is essential for building trust with stakeholders. Effective CSR reporting reflects accountability and can lead to better financial performance, particularly in regulated sectors like banking [Data: Reports (55)]. By adhering to established frameworks such as the Global Reporting Initiative (GRI), SAP can ensure that its sustainability disclosures meet regulatory standards, potentially increasing investor confidence [Data: Reports (98, 163)].
#
# ### 4. Leveraging Technology for Enhanced Reporting
#
# SAP should leverage its expertise in digitalization to enhance sustainability reporting and compliance with regulations. By providing tools that streamline Environmental, Social, and Governance (ESG) disclosures, SAP can assist banks in meeting regulatory requirements while improving their sustainability performance. This may lead to financial benefits through increased investor confidence and reduced compliance costs [Data: Reports (30, 92, 196, 240, 171, +more)].
#
# ### 5. Building Strategic Partnerships
#
# Forming partnerships with local banks and financial institutions can facilitate the implementation of sustainable practices that meet regulatory requirements while enhancing operational efficiency. Collaborative efforts can lead to shared knowledge and resources, ultimately driving financial performance through enhanced sustainability [Data: Reports (141, 107, 195, 212, 210, +more)]. Additionally, engaging with regulatory bodies can help SAP stay ahead of compliance requirements and influence policy development, positioning it as a leader in sustainability solutions for the banking sector [Data: Reports (141, 107, 195, 212, 210, +more)].
#
# ### Conclusion
#
# By focusing on these strategies, SAP can effectively align its sustainability initiatives with financial performance, ensuring that they lead to tangible benefits in the banking sector of Bangladesh. The integration of sustainability into core business strategies, coupled with a strong emphasis on regulatory compliance and stakeholder engagement, will be crucial for SAP's success in this highly regulated environment.
# Result for query: In what ways can SAP's corporate sustainability practices be tailored to align with the financial perceptions and expectations of Chinese stakeholders, especially in relation to the GRI Sustainability Reporting Guidelines? is: ## Tailoring SAP's Corporate Sustainability Practices for Chinese Stakeholders
#
# To effectively align SAP's corporate sustainability practices with the financial perceptions and expectations of Chinese stakeholders, particularly in relation to the GRI Sustainability Reporting Guidelines, several key strategies should be considered.
#
# ### Integration of GRI Guidelines
#
# SAP can enhance its sustainability practices by integrating the GRI Sustainability Reporting Guidelines, which emphasize transparency and accountability. This alignment is crucial as Chinese stakeholders increasingly value clear and comprehensive sustainability disclosures. By adopting these guidelines, SAP can demonstrate its commitment to sustainability, thereby improving its reputation and trust among stakeholders in China [Data: Reports (212, 210, 80, 118, 195)].
#
# ### Emphasizing Financial Metrics
#
# Incorporating financial metrics such as Return on Assets (ROA) and Tobin's q into sustainability reporting will resonate with Chinese stakeholders who prioritize economic outcomes alongside sustainability efforts. By showcasing how sustainability initiatives contribute to financial performance, SAP can align its corporate strategies with the expectations of Chinese investors who seek economic viability alongside environmental responsibility [Data: Reports (162, 157, 206, 138, 70)].
#
# ### Understanding Local Cultural Values
#
# Tailoring sustainability practices to include local cultural values and expectations is essential. SAP should consider the unique perspectives of Chinese stakeholders, such as the importance of community engagement and social responsibility. This approach will help SAP better align its sustainability initiatives with stakeholder expectations, fostering trust and collaboration [Data: Reports (212, 210, 80, 118, 195)].
#
# ### Compliance with Regulatory Landscape
#
# Aligning sustainability practices with the regulatory landscape in China, which increasingly emphasizes sustainability and corporate social responsibility, is vital. By ensuring compliance with local regulations and sustainability indicators, SAP can demonstrate its commitment to responsible business practices, which is valued by Chinese stakeholders [Data: Reports (210, 80, 118, 195)].
#
# ### Highlighting Financial Benefits
#
# SAP should focus on demonstrating the financial benefits of sustainability initiatives, such as cost savings from energy efficiency and the potential for increased market share through sustainable products. This approach will appeal to stakeholders who prioritize economic performance alongside environmental responsibility [Data: Reports (28, 158, 67, 200, 223, +more)].
#
# ### Engaging with Stakeholders
#
# Engaging with local stakeholders through initiatives that reflect their values and expectations can enhance SAP's reputation and foster trust. This includes addressing social indicators such as labor practices and community engagement, which are critical for stakeholders in China. Incorporating feedback from these stakeholders into SAP's sustainability strategies will ensure that the practices are relevant and effective [Data: Reports (95, 95, 95, 95, 95, +more)].
#
# ### Conclusion
#
# By integrating the GRI Sustainability Reporting Guidelines, emphasizing financial metrics, understanding local cultural values, complying with regulatory requirements, highlighting financial benefits, and engaging with stakeholders, SAP can effectively tailor its corporate sustainability practices to align with the financial perceptions and expectations of Chinese stakeholders. This comprehensive approach will not only enhance SAP's credibility but also strengthen its position in the Chinese market, ultimately leading to improved stakeholder trust and engagement.

# %%
print(evaluation_dataset)
# Out:
# EvaluationDataset(features=['user_input', 'response', 'reference'], len=5)

# %%
evaluator_llm = LangchainLLMWrapper(llm_sap)
#evaluator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

metrics = [
    FactualCorrectness(llm=evaluator_llm, mode="precision", name="FactualCorrectness_Precision"),
    FactualCorrectness(llm=evaluator_llm, mode="recall", name="FactualCorrectness_Recall"),
    FactualCorrectness(llm=evaluator_llm, mode="f1", name="FactualCorrectness_F1"),
    #Faithfulness(llm=evaluator_llm), 
]
results = evaluate(dataset=evaluation_dataset, metrics=metrics)
df_grag = results.to_pandas()
# Out:
# Evaluating: 100%|██████████| 15/15 [01:27<00:00,  5.84s/it]

# %%
pd.set_option('display.max_colwidth', 250) # default is 50 / None for unlimited
df_grag
# Out:
#                                                                                                                                                                                                                        user_input  \
# 0                               How can SAP leverage its human resource management practices to enhance corporate sustainability and simultaneously boost financial performance in a regional context like Podlaskie Voivodeship?
# 1                                                                 What role can SAP play in developing green product psychological ownership among its employees to reduce green confusion and enhance environmental performance?
# 2  In what ways can SAP's corporate sustainability practices be tailored to align with the financial perceptions and expectations of Chinese stakeholders, especially in relation to the GRI Sustainability Reporting Guidelines?
# 3                                                                              How can SAP address the challenges of high ownership concentration impacting corporate sustainability performance in emerging markets like Brazil?
# 4                                           What strategies can SAP adopt to ensure that its sustainability initiatives lead to tangible financial benefits, particularly in highly regulated sectors like banking in Bangladesh?
#
#                                                                                                                                                                                                                                                     response  \
# 0  ## Enhancing Corporate Sustainability through HRM Practices\n\nSAP can significantly enhance its corporate sustainability and financial performance in the Podlaskie Voivodeship by integrating sustainable human resource management (HRM) practices ...
# 1  ## Enhancing Green Product Psychological Ownership at SAP\n\nSAP can play a pivotal role in developing green product psychological ownership among its employees, which is essential for reducing green confusion and enhancing overall environmental ...
# 2  ## Tailoring SAP's Corporate Sustainability Practices for Chinese Stakeholders\n\nTo effectively align SAP's corporate sustainability practices with the financial perceptions and expectations of Chinese stakeholders, particularly in relation to t...
# 3  ## Addressing High Ownership Concentration in Corporate Sustainability\n\nHigh ownership concentration in emerging markets, particularly in Brazil, presents significant challenges for corporate sustainability performance. Companies with concentra...
# 4  ## Strategies for SAP to Enhance Financial Benefits from Sustainability Initiatives\n\nSAP can adopt several strategic approaches to ensure that its sustainability initiatives yield tangible financial benefits, especially in the highly regulated ...
#
#                                                                                                                                                                                                                                                    reference  \
# 0  SAP can leverage its HRM practices by implementing a Sustainable HRM framework that focuses on ecological, social, and strategic aspects. By promoting pro-environmental behaviors, enhancing diversity management, and supporting work-life balance, ...
# 1  SAP can play a pivotal role in developing green product psychological ownership by fostering a shared green vision and providing training that emphasizes the importance of sustainability in product design and functionality. By doing so, SAP can r...
# 2  To align SAP's corporate sustainability practices with Chinese stakeholders' financial perceptions, SAP should focus on enhancing the environmental and social aspects of its sustainability reports, as these are valued more by Chinese stakeholders...
# 3  In emerging markets like Brazil, high ownership concentration can negatively impact corporate sustainability performance by prioritizing short-term gains over long-term sustainability goals. SAP can address these challenges by promoting inclusive...
# 4  SAP can adopt strategies such as integrating sustainability criteria into financial decision-making processes and developing products that meet regulatory requirements while promoting environmental stewardship. In the heavily regulated banking se...
#
#    FactualCorrectness_Precision  FactualCorrectness_Recall  \
# 0                          0.19                       0.62
# 1                          0.13                       0.73
# 2                          0.62                       0.79
# 3                          0.37                       0.88
# 4                          0.35                       0.45
#
#    FactualCorrectness_F1
# 0                   0.29
# 1                   0.35
# 2                   0.70
# 3                   0.53
# 4                   0.29

# %%
average_metrics_grag = df_grag[['FactualCorrectness_Precision', 'FactualCorrectness_Recall', 'FactualCorrectness_F1']].mean().round(4)
average_metrics_rag = df_rag[['FactualCorrectness_Precision', 'FactualCorrectness_Recall', 'FactualCorrectness_F1']].mean().round(4)

print("Average for each metric (GraphRAG):")
print(average_metrics_grag)
print("Average for each metric (RAG):")
print(average_metrics_rag)
# Out:
# Average for each metric (GraphRAG):
# FactualCorrectness_Precision    0.332
# FactualCorrectness_Recall       0.694
# FactualCorrectness_F1           0.432
# dtype: float64
# Average for each metric (RAG):
# FactualCorrectness_Precision    0.512
# FactualCorrectness_Recall       0.350
# FactualCorrectness_F1           0.430
# dtype: float64
