# %% [markdown]
# # Imports and load data

# %%
from dotenv import load_dotenv
from rag_utils import setup_rag_embeddings, build_rag_chain
from ragas import SingleTurnSample, EvaluationDataset, evaluate
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from ragas.metrics import FactualCorrectness
from gen_ai_hub.proxy.langchain.openai import ChatOpenAI as ChatOpenAIProxy
from gen_ai_hub.proxy.core.proxy_clients import get_proxy_client
from langchain_openai import OpenAIEmbeddings, ChatOpenAI

import asyncio
import pandas as pd
import os
import json

load_dotenv(override=True)

model_name = "gpt-4o-mini"
model_name_SAP = "gpt-4o"
DATA_DIR = "input_big_context/"
DATASET = "evaluation_dataset_big_context.json"
TEMP = "temp_large_context/"

proxy_client = get_proxy_client('gen-ai-hub')
llm_sap = ChatOpenAIProxy(proxy_model_name=model_name_SAP, proxy_client=proxy_client)
llm = ChatOpenAI(model=model_name, temperature=0)
#embeddings_model = OpenAIEmbeddings(proxy_model_name='text-embedding-ada-002', proxy_client=proxy_client)
embeddings_model_own = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
# only for parsing the pdf reports to markdown for the first time
"""
for file in os.listdir(DATA_DIR):
    if file.endswith(".pdf"):
        try:
            print(f"Converting {file} to markdown")
            md_text = LlamaParse(
                result_type="markdown", 
                verbose=True,
                #use_vendor_multimodal_model=True,
                #vendor_multimodal_model_name="openai-gpt-4o-mini",
                #vendor_multimodal_api_key=os.getenv("OPENAI_API_KEY"),
                language="en",
                numWorkers=5).load_data(DATA_DIR + file)
            combined_md_text = "\n\n".join([doc.text for doc in md_text])
            md_file_path = DATA_DIR + file.replace(".pdf", ".md")
            print(f"Saving markdown to {md_file_path}")
            with open(md_file_path, "w", encoding="utf-8") as f:
                f.write(combined_md_text)
            print(f"Successfully converted {file}")
        except Exception as e:
            print(f"Error converting {file}: {e}")
"""

# %% [markdown]
# # RAG

# %%
#setup embeddings and chain
retriever = setup_rag_embeddings(data_dir=DATA_DIR, faiss_path="faiss_big_context", embeddings_model=embeddings_model_own)
rag_chain = build_rag_chain(retriever=retriever, llm=llm)
# Out:
# Embedding documents...
# amount of documents used:  4
# Saved 5029 chunks to faiss_big_context.
# e:\Repositories\graphrag-businessqa-evaluation\.conda\Lib\site-packages\langsmith\client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# prompt input_variables=['context', 'question'] input_types={} partial_variables={} metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})]

# %% [markdown]
# Map generated questions and ground_truths into evaluation dataset

# %%
with open(DATASET, 'r') as f:
    synthetic_data = json.load(f)

if isinstance(synthetic_data, dict) and 'responses' in synthetic_data:
    synthetic_data = synthetic_data['responses']

queries = [item.get('question', "") for item in synthetic_data]
ground_truths = [item.get('ground_truth', "") for item in synthetic_data]
contexts = [item.get('context', "") for item in synthetic_data]

answers = []
retrieved_contexts = []

for query in queries:
    answer = rag_chain.invoke(query)
    answers.append(answer)
    print("Query: ",query)
    print("Anwer: ",answer)
    retrieved_context = [doc.page_content for doc in retriever.invoke(query)]
    retrieved_contexts.append(retrieved_context)
    print("Retrieved context:",retrieved_context)
# Out:
# Query:  How can SAP leverage generative AI to enhance its sustainability solutions, enabling customers to more effectively track and reduce their carbon footprints while simultaneously improving the efficiency of their internal processes?
# Anwer:  SAP can leverage generative AI to enhance its sustainability solutions by embedding AI capabilities across its portfolio, enabling customers to systematically track and manage their carbon emissions. This integration simplifies user interactions and improves operational efficiency, allowing organizations to take effective action towards sustainability. Additionally, SAP's focus on AI-driven efficiencies supports its goal of helping customers reduce their environmental impact while optimizing internal processes.
# Retrieved context: ['SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'the topic of sustainability at SAP based on a detailed meeting document that highlighted, in particular, SAP’s goal to emit zero greenhouse gas emissions from 2030 onwards, general human rights topics, the German Supply Chain Due Diligence Act, and best practices for responsible AI.', 'All these global developments have a direct relevance for SAP. Our solutions touch 87% of global commerce and help keep companies, economies, and global business resilient in volatile times. Our sustainability offering enables customers to systematically track key metrics, including carbon emissions, and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.', '- SAP delivers sustainability management solutions for sustainability reporting, climate action, circular economy, and social responsibility to enable our customers to run sustainable and resilient operations as described in the Product Strategy section.', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'Our purpose at SAP remains steadfast: to “help the world run better and improve people’s lives.” We strive to achieve this by focusing on the challenges of current markets, the global environment, and by using the transformative power of artificial intelligence (AI) in business. SAP combines generative AI with business data. We are committed to providing AI solutions that are integral to our', '- We started to develop a carbon footprint sizing approach with the aim of enabling our customers to gain transparency on the carbon impact of their SAP applications that run in SAP’s internal and external data centers, answering the question of how much our customers can reduce their environmental footprint while running SAP solutions on SAP’s self-operated or on SAP sourced infrastructure.']
# Query:  Considering the increasing importance of ESG factors, how can SAP integrate sustainable practices into its core business operations, including its data centers and supply chain, to minimize its environmental impact and enhance its brand reputation?
# Anwer:  SAP can integrate sustainable practices by optimizing energy consumption in its data centers and ensuring procurement of energy-efficient products. The company also emphasizes compliance with environmental standards like ISO 14001:2015 and LEED certification in its facilities management. Additionally, SAP's green ledger initiative supports data-driven sustainability by enabling organizations to record and report ESG metrics effectively.
# Retrieved context: ['in two different ways: by offering solutions that empower SAP customers to become more sustainable enterprises, and by aligning its own business activities with ESG (environmental, social, and governance) goals and targets. The entire spectrum of SAP’s sustainability efforts and sustainability solutions is a cross topic that is monitored and covered by several committees. That is why the', "SAP recognizes the interdependencies between today's environmental and social issues, approaching them with a sustainable corporate strategy. Corporate social responsibility (CSR) is part of that strategy, embodying SAP’s purpose to help the world run better and improve people’s lives. CSR at SAP focuses on driving long-term social and environmental impact and business value with three focus", 'We continued our dialogue with investors, focusing on environmental, social, and governance (ESG) topics and providing them with insights into our sustainability policies and products. SAP’s leadership in this area has been recognized by leading sustainability rating organizations.', 'Due to the comprehensive strategic importance that sustainability has for SAP and its customers, the Supervisory Board addressed the sustainability aspects that are relevant to SAP numerous times throughout the fiscal year 2023. It is important to note here that SAP promotes sustainability in two different ways: by offering solutions that empower SAP customers to become more sustainable', 'We have evolved beyond mere sustainability aspirations to actionable, sustainable outcomes. SAP’s green ledger initiative provides auditable sustainability practices as an extension of business operations. This approach enables organizations to record real impacts, report audit-ready ESG metrics, and act with ESG principles integrated into business processes, supporting data-driven sustainability', 'Sustainability is a company-wide effort, and initiatives are also driven outside this dedicated unit. For example, the global procurement organization aims to ensure that SAP purchases energy-efficient, sustainable products and services. The global real estate and facilities management team designs and operates many SAP facilities based on robust environmental standards such as ISO 14001:2015 and', '1. SAP as enabler: We strive to provide products and services that support our customers in meeting their sustainability challenges and in capitalizing on the related opportunities.\n2. SAP as exemplar: To live up to our corporate responsibility and to build resilience, we strive toward leading by example in SAP’s business operations and practices by running our own operations more sustainably.', 'and operates many SAP facilities based on robust environmental standards such as ISO 14001:2015 and the Leadership in Energy and Environmental Design (LEED) certification program. Our global cloud services organization attends to the optimization of the energy consumption in our data centers, while our SAP IT department encourages employees to use IT equipment and business software responsibly.', 'the topic of sustainability at SAP based on a detailed meeting document that highlighted, in particular, SAP’s goal to emit zero greenhouse gas emissions from 2030 onwards, general human rights topics, the German Supply Chain Due Diligence Act, and best practices for responsible AI.', '- SAP delivers sustainability management solutions for sustainability reporting, climate action, circular economy, and social responsibility to enable our customers to run sustainable and resilient operations as described in the Product Strategy section.']
# Query:  Given the rapid advancements in AI, how can SAP strategically invest in research and development to maintain its leadership position in enterprise applications while simultaneously expanding its capabilities in business AI and generative AI?
# Anwer:  SAP can strategically invest in research and development by focusing on strong partnerships with leading AI companies and committing nearly €1 billion to develop AI use cases. Additionally, SAP plans to enhance its workforce's AI expertise and implement a transformation program to prioritize business AI, ensuring scalability and efficiency. This approach will help maintain its leadership in enterprise applications while expanding capabilities in business and generative AI.
# Retrieved context: ['SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'current and future investments to expand its AI portfolio. In addition, management explained to us its plans for building up additional AI expertise among SAP’s workforce. The Go-to-Market and Operations Committee analyzed the success of the go-to-market measures for AI at its October meeting.', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'Strong partnerships and collaborations with leading AI companies – including Nvidia, Microsoft, and OpenAI, as well as Google – will help SAP to further expand the capabilities of our business AI solutions and to maximize their benefit for our customers.', 'invest almost €1 billion to develop powerful AI use cases for our customers. And, with a dedicated transformation program, we intend to further intensify the shift of resources to business AI, in line with the significant growth potential we see for SAP. The planned program will also include a restructuring component focusing on reskilling and voluntary exits. A decision affecting colleagues this', 'One of the main focuses of our discussions with the Executive Board was the topic of artificial intelligence (“AI”). SAP is working intensively to integrate AI in its software solutions to allow customers to reap the enormous potential of using AI. The Supervisory Board supports and continually monitors this process and the measures associated with it. At our meeting on February 22, 2023, for', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'We are integrating AI into a number of our products, including our suite of enterprise applications and SAP BTP, and we expect our use of AI across our portfolio to continue to grow. As with many innovations, AI presents risks and challenges that could affect its adoption and therefore our business. AI algorithms or training methodologies may be flawed. Data sets may be overbroad, insufficient,', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.']
# Query:  How can SAP utilize AI to optimize its global supply chain, improving efficiency, reducing costs, and mitigating risks associated with geopolitical instability and climate change impacts?
# Anwer:  SAP can utilize AI to optimize its global supply chain by embedding AI capabilities across its enterprise applications, enabling automation, forecasting, and enhanced decision-making. This integration helps improve efficiency, reduce costs, and mitigate risks related to geopolitical instability and climate change by providing real-time insights and recommendations. Additionally, SAP's focus on sustainability allows customers to track and manage key metrics, further enhancing resilience in volatile environments.
# Retrieved context: ['To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'All these global developments have a direct relevance for SAP. Our solutions touch 87% of global commerce and help keep companies, economies, and global business resilient in volatile times. Our sustainability offering enables customers to systematically track key metrics, including carbon emissions, and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'SAP Business AI refers to artificial intelligence (AI) capabilities available across SAP’s suite of enterprise applications and SAP BTP. SAP offers a range of AI-powered use cases built into core business processes across finance, supply chain, procurement, sales, marketing, human resources, and IT. By using these AI capabilities, customers can benefit from automation, recommendations,', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'and IT. By using these AI capabilities, customers can benefit from automation, recommendations, forecasting, and natural human-machine interaction. In addition, SAP BTP provides business-specific AI services that empower our partners and customers to implement AI into their SAP applications and extensions while reducing data science effort, integration, and operational complexity.', '- SAP’s holistic approach to the future of work actively addresses trends and developments – including the AI revolution and skills shortage – to reimagine work at its core. We drive this transformation with state-of-the-art people practices and innovative workplace approaches to future-proof our organization in times of unprecedented change.']
# Query:  In what ways can SAP leverage AI to enhance its customer experience, improving customer loyalty and satisfaction while simultaneously reducing operational costs and increasing efficiency?
# Anwer:  SAP can leverage AI to enhance customer experience by integrating AI capabilities across its enterprise applications, enabling automation, personalized recommendations, and improved forecasting. This approach not only increases customer satisfaction and loyalty but also reduces operational costs and enhances efficiency through streamlined processes. Additionally, partnerships with leading AI companies will further expand SAP's AI capabilities, maximizing benefits for customers.
# Retrieved context: ['SAP Business AI refers to artificial intelligence (AI) capabilities available across SAP’s suite of enterprise applications and SAP BTP. SAP offers a range of AI-powered use cases built into core business processes across finance, supply chain, procurement, sales, marketing, human resources, and IT. By using these AI capabilities, customers can benefit from automation, recommendations,', 'and IT. By using these AI capabilities, customers can benefit from automation, recommendations, forecasting, and natural human-machine interaction. In addition, SAP BTP provides business-specific AI services that empower our partners and customers to implement AI into their SAP applications and extensions while reducing data science effort, integration, and operational complexity.', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'One of the main focuses of our discussions with the Executive Board was the topic of artificial intelligence (“AI”). SAP is working intensively to integrate AI in its software solutions to allow customers to reap the enormous potential of using AI. The Supervisory Board supports and continually monitors this process and the measures associated with it. At our meeting on February 22, 2023, for', 'Strong partnerships and collaborations with leading AI companies – including Nvidia, Microsoft, and OpenAI, as well as Google – will help SAP to further expand the capabilities of our business AI solutions and to maximize their benefit for our customers.']
# Query:  Considering the potential risks associated with AI, such as bias and data privacy, how can SAP develop and implement ethical guidelines and robust security measures to ensure responsible AI development and deployment?
# Anwer:  SAP can develop and implement ethical guidelines by adhering to its Global AI Ethics Policy, which aligns AI development with established ethical standards. The Artificial Intelligence Ethics Steering Committee, comprising SAP executives and external experts, guides the enforcement of these ethics in operations and solutions. Additionally, SAP emphasizes the importance of robust security measures to mitigate risks associated with flawed algorithms and biased data sets.
# Retrieved context: ['In addition, our Global AI Ethics Policy helps ensure that our artificial intelligence (AI) software is developed, deployed, and sold in line with the ethical standards laid out in our guiding principles. This policy and guiding principles are available at AI Ethics and Society | SAP.\n\n# How We Measure and Manage Our Performance\n\n# Identifying Salient Human Rights Issues', 'AI algorithms or training methodologies may be flawed. Data sets may be overbroad, insufficient, or contain biased information. Content generated by AI systems may be offensive, illegal, or otherwise harmful. Ineffective or inadequate AI development or deployment practices by SAP or our partners could result in incidents that impair the acceptance of AI solutions or cause harm to individuals,', 'Grounded in our commitment to respecting human rights, the Artificial Intelligence (AI) Ethics Steering Committee guides our internal efforts to implement and enforce AI ethics in our operations, solutions, and policies. It comprises SAP executives from relevant Board areas with supervision of topics relevant to guiding and implementing AI ethics. Made up of experts from academia, industry, and', 'One of the main focuses of our discussions with the Executive Board was the topic of artificial intelligence (“AI”). SAP is working intensively to integrate AI in its software solutions to allow customers to reap the enormous potential of using AI. The Supervisory Board supports and continually monitors this process and the measures associated with it. At our meeting on February 22, 2023, for', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'relevant to guiding and implementing AI ethics. Made up of experts from academia, industry, and public policy, our external AI Ethics Advisory Panel advises us on how to further develop and operationalize SAP’s Guiding Principles for Artificial Intelligence.', 'We are integrating AI into a number of our products, including our suite of enterprise applications and SAP BTP, and we expect our use of AI across our portfolio to continue to grow. As with many innovations, AI presents risks and challenges that could affect its adoption and therefore our business. AI algorithms or training methodologies may be flawed. Data sets may be overbroad, insufficient,', '# Other Potential Risks\n\nThe rise of AI also brings a set of societal and ethical risks that must be managed vigilantly. It is important to have a set of clear principles that guide the development and use of AI. For example, Google has outlined the following seven key principles for its development of AI applications:', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'or might not be sufficiently secure after release or shipment despite all the due diligence SAP puts into quality; inability of algorithms to correctly adapt to evolving circumstances, which may lead to adverse decision-making processes in the context of AI-related technologies; and the inability to fulfil expectations of customers regarding time and quality in the defect resolution process. Any']
# Query:  How can SAP leverage AI to improve its risk management capabilities, identifying and mitigating potential threats to its business while simultaneously enhancing its resilience to economic downturns and geopolitical instability?
# Anwer:  SAP can leverage AI to enhance its risk management by integrating AI capabilities across its enterprise applications, which can automate processes and provide data-driven recommendations for identifying potential threats. By continuously monitoring regulatory changes and investing in AI technologies, SAP aims to improve its resilience against economic and geopolitical challenges. Additionally, the company's focus on predictable revenue streams from cloud subscriptions can help stabilize its financial position during downturns.
# Retrieved context: ['To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'We are integrating AI into a number of our products, including our suite of enterprise applications and SAP BTP, and we expect our use of AI across our portfolio to continue to grow. As with many innovations, AI presents risks and challenges that could affect its adoption and therefore our business. AI algorithms or training methodologies may be flawed. Data sets may be overbroad, insufficient,', 'SAP Business AI refers to artificial intelligence (AI) capabilities available across SAP’s suite of enterprise applications and SAP BTP. SAP offers a range of AI-powered use cases built into core business processes across finance, supply chain, procurement, sales, marketing, human resources, and IT. By using these AI capabilities, customers can benefit from automation, recommendations,', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'SAP has established measures intended to address and mitigate the described risks and adverse effects. For example, we: monitor new and increased regulatory requirements; continuously invest in, improve, and standardize our global processes, procedures, and solutions; proactively assess newly emerging regulatory initiatives; consult external economic and tax advisors, law firms, and authorities', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'SAP has established measures intended to address and mitigate the described risks and adverse effects. For example, we: continuously align our organization, processes, products, delivery, commercial and consumption models, and services to changing markets and customer and partner demands; continuously benchmark, match, and challenge the entire portfolio; focus all investment decisions related to', 'SAP has established measures intended to address and mitigate the described risks and adverse effects. For example, we increase our share of more predictable revenue streams from cloud subscriptions and software support revenue streams, providing increased stability against financial volatility; and, supported by our global government affairs unit, we continuously monitor and evaluate global and', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'One of the main focuses of our discussions with the Executive Board was the topic of artificial intelligence (“AI”). SAP is working intensively to integrate AI in its software solutions to allow customers to reap the enormous potential of using AI. The Supervisory Board supports and continually monitors this process and the measures associated with it. At our meeting on February 22, 2023, for']
# Query:  How can SAP utilize AI to enhance its sales and marketing efforts, increasing revenue and market share while simultaneously improving customer engagement and brand loyalty?
# Anwer:  SAP can enhance its sales and marketing efforts by embedding AI capabilities across its enterprise applications, which allows for automation, personalized recommendations, and improved forecasting. By leveraging partnerships with leading AI companies and focusing on business AI, SAP aims to increase customer engagement and brand loyalty while expanding its market share. The company's transformation program for 2024 will further drive AI-driven efficiencies and scalable revenue growth.
# Retrieved context: ['SAP Business AI refers to artificial intelligence (AI) capabilities available across SAP’s suite of enterprise applications and SAP BTP. SAP offers a range of AI-powered use cases built into core business processes across finance, supply chain, procurement, sales, marketing, human resources, and IT. By using these AI capabilities, customers can benefit from automation, recommendations,', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'and IT. By using these AI capabilities, customers can benefit from automation, recommendations, forecasting, and natural human-machine interaction. In addition, SAP BTP provides business-specific AI services that empower our partners and customers to implement AI into their SAP applications and extensions while reducing data science effort, integration, and operational complexity.', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'Strong partnerships and collaborations with leading AI companies – including Nvidia, Microsoft, and OpenAI, as well as Google – will help SAP to further expand the capabilities of our business AI solutions and to maximize their benefit for our customers.', 'current and future investments to expand its AI portfolio. In addition, management explained to us its plans for building up additional AI expertise among SAP’s workforce. The Go-to-Market and Operations Committee analyzed the success of the go-to-market measures for AI at its October meeting.']
# Query:  How can SAP leverage AI to improve its talent acquisition and development strategies, attracting and retaining top talent while simultaneously fostering a diverse and inclusive workplace?
# Anwer:  SAP can leverage AI to enhance its talent acquisition and development by utilizing advanced people practices and innovative workplace approaches that focus on attracting diverse talent and continuously upskilling employees. By embedding AI capabilities across its portfolio, SAP aims to simplify interactions with its solutions, thereby increasing engagement and retention. Additionally, fostering an inclusive culture that values human differences will further support SAP's goal of becoming the world's most inclusive workplace.
# Retrieved context: ['- Build SAP’s Skills for the Future by attracting the best and most diverse talent and continuously up-/reskilling our people\n- Drive SAP’s Winning and Inclusive Culture by fostering a culture that enables and rewards impact and business outcomes and nurtures inclusion and belonging', '- SAP’s holistic approach to the future of work actively addresses trends and developments – including the AI revolution and skills shortage – to reimagine work at its core. We drive this transformation with state-of-the-art people practices and innovative workplace approaches to future-proof our organization in times of unprecedented change.', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'SAP is committed to accelerating cloud growth. This requires workforce upskilling and expansion. Attracting, hiring, onboarding, developing, and retaining top talent is vital for our future success. In 2023, we focused on internal roles and strategic investment areas to support our transformation and long-term growth. The competitive talent market underscores the need to further communicate our', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'At SAP, we strive to be the world’s most inclusive workplace, aiming to create a unique culture where everyone feels a sense of belonging, and human differences are celebrated and valued. As a global organization with employees from 160 nationalities, we strive to consider the full spectrum of human differences and promote inclusion for each one of them (for example, inclusion of gender, race,', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'One of the main focuses of our discussions with the Executive Board was the topic of artificial intelligence (“AI”). SAP is working intensively to integrate AI in its software solutions to allow customers to reap the enormous potential of using AI. The Supervisory Board supports and continually monitors this process and the measures associated with it. At our meeting on February 22, 2023, for', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.']
# Query:  How can SAP utilize AI to enhance its product development process, accelerating innovation and improving product quality while simultaneously reducing costs and time to market?
# Anwer:  SAP can enhance its product development process by integrating AI capabilities across its suite of enterprise applications, which allows for automation, recommendations, and improved forecasting. This integration not only accelerates innovation and improves product quality but also reduces costs and time to market through streamlined operations. Additionally, strategic partnerships with leading AI companies will further expand SAP's AI capabilities, maximizing benefits for customers.
# Retrieved context: ['SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'SAP Business AI refers to artificial intelligence (AI) capabilities available across SAP’s suite of enterprise applications and SAP BTP. SAP offers a range of AI-powered use cases built into core business processes across finance, supply chain, procurement, sales, marketing, human resources, and IT. By using these AI capabilities, customers can benefit from automation, recommendations,', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'We are integrating AI into a number of our products, including our suite of enterprise applications and SAP BTP, and we expect our use of AI across our portfolio to continue to grow. As with many innovations, AI presents risks and challenges that could affect its adoption and therefore our business. AI algorithms or training methodologies may be flawed. Data sets may be overbroad, insufficient,', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'and IT. By using these AI capabilities, customers can benefit from automation, recommendations, forecasting, and natural human-machine interaction. In addition, SAP BTP provides business-specific AI services that empower our partners and customers to implement AI into their SAP applications and extensions while reducing data science effort, integration, and operational complexity.', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'Strong partnerships and collaborations with leading AI companies – including Nvidia, Microsoft, and OpenAI, as well as Google – will help SAP to further expand the capabilities of our business AI solutions and to maximize their benefit for our customers.']
# Query:  Considering the growing importance of sustainability, how can SAP leverage its technology and expertise to help its customers achieve their own sustainability goals, creating new revenue streams and strengthening its market position?
# Anwer:  SAP can leverage its technology and expertise by providing sustainability solutions that help customers manage their sustainability challenges and capitalize on related opportunities. By offering products like SAP Cloud for Sustainable Enterprises and initiatives such as RISE with SAP, the company supports customers in achieving their sustainability goals while enhancing their own market position. Additionally, SAP's commitment to running its operations sustainably and achieving carbon neutrality reinforces its role as a leader in the sustainability space.
# Retrieved context: ['Due to the comprehensive strategic importance that sustainability has for SAP and its customers, the Supervisory Board addressed the sustainability aspects that are relevant to SAP numerous times throughout the fiscal year 2023. It is important to note here that SAP promotes sustainability in two different ways: by offering solutions that empower SAP customers to become more sustainable', 'in two different ways: by offering solutions that empower SAP customers to become more sustainable enterprises, and by aligning its own business activities with ESG (environmental, social, and governance) goals and targets. The entire spectrum of SAP’s sustainability efforts and sustainability solutions is a cross topic that is monitored and covered by several committees. That is why the', '1. SAP as enabler: We strive to provide products and services that support our customers in meeting their sustainability challenges and in capitalizing on the related opportunities.\n2. SAP as exemplar: To live up to our corporate responsibility and to build resilience, we strive toward leading by example in SAP’s business operations and practices by running our own operations more sustainably.', '# Further Information about Sustainability\n\n# Additional Information\n\nFurther, SAP strives to help customers grow their businesses profitably, while at the same time minimizing the risks. To this end, SAP has two offerings, RISE with SAP and GROW with SAP, which cater to different customer objectives and requirements.\n\n# RISE with SAP', '# Sustainability Management\n\nSAP offers sustainability solutions and services that can help customers drive sustainable practices not only inside their organization but across the entire value chain. SAP Cloud for Sustainable Enterprises is a flexible solution portfolio that aims to enable businesses to manage sustainability.\n\n# SAP Integrated Report 2023\n\n# To Our Stakeholders', '- SAP delivers sustainability management solutions for sustainability reporting, climate action, circular economy, and social responsibility to enable our customers to run sustainable and resilient operations as described in the Product Strategy section.', 'Beyond the convincing financial performance, SAP also met its non-financial goals. In 2023, SAP achieved carbon neutrality in its own operations and continues to focus on achieving net zero by 2030 along our value chain. Further, we intend to make an even bigger contribution to sustainability by helping our customers accelerate their respective journeys. Roughly 1,000 new customers chose SAP’s', 'helping our customers accelerate their respective journeys. Roughly 1,000 new customers chose SAP’s sustainability solutions in 2023 alone.', '# Additional Information\n\n# Sustainability Management\n\nAt the heart of our strategy to bring SAP’s purpose of “helping the world run better and improving people’s lives” to life, sustainability is firmly anchored in our business strategy, governance, and executive compensation system. For more information about our corporate strategy, see the Strategy section.', 'We have evolved beyond mere sustainability aspirations to actionable, sustainable outcomes. SAP’s green ledger initiative provides auditable sustainability practices as an extension of business operations. This approach enables organizations to record real impacts, report audit-ready ESG metrics, and act with ESG principles integrated into business processes, supporting data-driven sustainability']
# Query:  How can SAP utilize AI to improve its financial forecasting and planning capabilities, enhancing its decision-making processes and improving its overall financial performance?
# ...
# Query:  How can SAP utilize AI to improve its product pricing and revenue management strategies, maximizing profitability while simultaneously maintaining customer satisfaction and market competitiveness?
# Anwer:  SAP can utilize AI to enhance product pricing and revenue management by embedding AI capabilities across its enterprise applications, enabling automation, forecasting, and personalized recommendations. This integration allows for more accurate pricing strategies that align with market demand while improving customer satisfaction. Additionally, SAP's focus on AI-driven efficiencies and scalability positions it to remain competitive in the market.
# Retrieved context: ['implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'SAP Business AI refers to artificial intelligence (AI) capabilities available across SAP’s suite of enterprise applications and SAP BTP. SAP offers a range of AI-powered use cases built into core business processes across finance, supply chain, procurement, sales, marketing, human resources, and IT. By using these AI capabilities, customers can benefit from automation, recommendations,', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'and IT. By using these AI capabilities, customers can benefit from automation, recommendations, forecasting, and natural human-machine interaction. In addition, SAP BTP provides business-specific AI services that empower our partners and customers to implement AI into their SAP applications and extensions while reducing data science effort, integration, and operational complexity.', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'current and future investments to expand its AI portfolio. In addition, management explained to us its plans for building up additional AI expertise among SAP’s workforce. The Go-to-Market and Operations Committee analyzed the success of the go-to-market measures for AI at its October meeting.', 'One of the main focuses of our discussions with the Executive Board was the topic of artificial intelligence (“AI”). SAP is working intensively to integrate AI in its software solutions to allow customers to reap the enormous potential of using AI. The Supervisory Board supports and continually monitors this process and the measures associated with it. At our meeting on February 22, 2023, for', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.']
# Query:  How can SAP utilize AI to improve its supply chain resilience, mitigating risks associated with disruptions and geopolitical instability while simultaneously enhancing its overall operational efficiency?
# Anwer:  SAP can enhance supply chain resilience by embedding AI capabilities across its enterprise applications, which allows for automation and improved decision-making in response to disruptions and geopolitical instability. By leveraging AI for predictive analytics and real-time data insights, SAP can help organizations mitigate risks and optimize their operations. This integration not only improves efficiency but also supports sustainability efforts by enabling better tracking of key metrics.
# Retrieved context: ['To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'All these global developments have a direct relevance for SAP. Our solutions touch 87% of global commerce and help keep companies, economies, and global business resilient in volatile times. Our sustainability offering enables customers to systematically track key metrics, including carbon emissions, and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our', 'SAP Business AI refers to artificial intelligence (AI) capabilities available across SAP’s suite of enterprise applications and SAP BTP. SAP offers a range of AI-powered use cases built into core business processes across finance, supply chain, procurement, sales, marketing, human resources, and IT. By using these AI capabilities, customers can benefit from automation, recommendations,', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology to embed AI across SAP’s portfolio. The Company anticipates significant possibilities for market expansion through these technologies and new premium offerings.', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.', 'We are integrating AI into a number of our products, including our suite of enterprise applications and SAP BTP, and we expect our use of AI across our portfolio to continue to grow. As with many innovations, AI presents risks and challenges that could affect its adoption and therefore our business. AI algorithms or training methodologies may be flawed. Data sets may be overbroad, insufficient,', '- SAP’s holistic approach to the future of work actively addresses trends and developments – including the AI revolution and skills shortage – to reimagine work at its core. We drive this transformation with state-of-the-art people practices and innovative workplace approaches to future-proof our organization in times of unprecedented change.']
# Query:  How can SAP leverage its technology and expertise to help its customers address the challenges of climate change, creating new revenue streams and strengthening its market position?
# Anwer:  SAP can leverage its technology and expertise by providing sustainability management solutions that help customers address climate challenges while creating new revenue streams. By enabling customers to track key metrics like carbon emissions and implement effective climate actions, SAP positions itself as a leader in sustainability. Additionally, SAP's commitment to running its operations sustainably and achieving net zero by 2030 enhances its market position and corporate responsibility.
# Retrieved context: ['For over a decade now, climate action has been at the top of SAP’s corporate sustainability agenda in light of the increasing impacts of climate change and escalating global challenges such as ecosystem degradation and biodiversity loss. As outlined in the Sustainability Management40 section, we aim to take climate action through our dual approach as enabler and exemplar to help pave the way', '|Strategy|Actual and potential impacts of climate-related risks and opportunities on SAP’s businesses, strategy, and financial planning where such information is material.|Energy and Emissions Sustainability Management Risk Management and Risks Strategy|\n|Risk Management|How does SAP identify, assess, and manage climate-related risks?|Energy and Emissions|', '- SAP delivers sustainability management solutions for sustainability reporting, climate action, circular economy, and social responsibility to enable our customers to run sustainable and resilient operations as described in the Product Strategy section.', 'aim to take climate action through our dual approach as enabler and exemplar to help pave the way toward a low-carbon future for our customers, partners, and SAP, and create impact within planetary boundaries.', '|Indirect:|Cloud powered by 100% renewable electricity; Business ambition for 1.5°C; SAP Cloud for Sustainable Enterprises; SAP’s solutions for climate action: SAP Sustainability Footprint Management; SAP Sustainability Data Exchange; SAP E-Mobility; SAP Landscape Management Cloud; SAP Transportation Management; SAP Environment, Health and Safety Management; SAP Cloud for Energy; SAP Concur; SAP', 'Beyond the convincing financial performance, SAP also met its non-financial goals. In 2023, SAP achieved carbon neutrality in its own operations and continues to focus on achieving net zero by 2030 along our value chain. Further, we intend to make an even bigger contribution to sustainability by helping our customers accelerate their respective journeys. Roughly 1,000 new customers chose SAP’s', '1. SAP as enabler: We strive to provide products and services that support our customers in meeting their sustainability challenges and in capitalizing on the related opportunities.\n2. SAP as exemplar: To live up to our corporate responsibility and to build resilience, we strive toward leading by example in SAP’s business operations and practices by running our own operations more sustainably.', 'in two different ways: by offering solutions that empower SAP customers to become more sustainable enterprises, and by aligning its own business activities with ESG (environmental, social, and governance) goals and targets. The entire spectrum of SAP’s sustainability efforts and sustainability solutions is a cross topic that is monitored and covered by several committees. That is why the', '|Direct:|Assume responsibility for products in use-related emissions by running customer applications in the SAP cloud powered with 100% renewable electricity|\n|---|---|\n| |Emit greenhouse gases|\n|Indirect:|Contribute to climate change mitigation and strengthen resilience and adaptive capacity to climate-related hazards and natural disasters of our customers|', 'All these global developments have a direct relevance for SAP. Our solutions touch 87% of global commerce and help keep companies, economies, and global business resilient in volatile times. Our sustainability offering enables customers to systematically track key metrics, including carbon emissions, and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our']

# %%
# populate eval dataset

evaluation_samples = []

for query, answer, retrieved_context, ground_truth in zip(queries, answers, retrieved_contexts, ground_truths):
    sample = SingleTurnSample(
        user_input=query,
        response=answer,
        reference=ground_truth,
        retrieved_contexts=retrieved_context
    )
    evaluation_samples.append(sample)

evaluation_dataset = EvaluationDataset(samples=evaluation_samples)

# %%
print(evaluation_dataset.samples)
print(type(evaluation_dataset.samples))
print(type(evaluation_dataset.samples[0]))
print(dir(evaluation_dataset.samples[0]))
# Out:
# [SingleTurnSample(user_input='How can SAP leverage generative AI to enhance its sustainability solutions, enabling customers to more effectively track and reduce their carbon footprints while simultaneously improving the efficiency of their internal processes?', retrieved_contexts=['SAP has been an early adopter of AI technology. During the SAP Sapphire conference in May, the Company showcased the use of AI in various products. At the beginning of the second half of 2023, the Company announced strategic direct investments in three leading generative AI companies. The investments underscore SAP’s open ecosystem approach to AI, which is aimed at leveraging the best technology', 'To address new and critical environmental, economic, and social challenges, SAP embeds SAP Business AI capabilities across our entire portfolio, a step we believe will increase customer demand. In addition, SAP Business AI has the potential to simplify how people interact with SAP solutions, and to increase the addressable user base.', 'the topic of sustainability at SAP based on a detailed meeting document that highlighted, in particular, SAP’s goal to emit zero greenhouse gas emissions from 2030 onwards, general human rights topics, the German Supply Chain Due Diligence Act, and best practices for responsible AI.', 'All these global developments have a direct relevance for SAP. Our solutions touch 87% of global commerce and help keep companies, economies, and global business resilient in volatile times. Our sustainability offering enables customers to systematically track key metrics, including carbon emissions, and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our', 'and to take effective action. Meanwhile, SAP is increasingly embedding business AI in all our solutions. We’re doing our part to make the technology a powerful, readily accessible tool for organizations to become more efficient, more sustainable, and more innovative.', '- SAP delivers sustainability management solutions for sustainability reporting, climate action, circular economy, and social responsibility to enable our customers to run sustainable and resilient operations as described in the Product Strategy section.', 'implementation of SAP’s enterprise AI strategy and examined the framework conditions for data consumption by AI applications. SAP’s AI strategy was also the subject of intense debate at the plenary meeting in July 2023. Among other things, our discussions focused on the go-to-market strategy and SAP’s current and future investments to expand its AI portfolio. In addition, management explained to', 'To further drive the aforementioned opportunities, SAP announced a transformation program for 2024 to focus on key strategic growth areas, in particular business AI. Through this program, SAP intends to transform its operational setup to capture organizational synergies and AI-driven efficiencies, and to prepare the Company for highly scalable future revenue growth.', 'Our purpose at SAP remains steadfast: to “help the world run better and improve people’s lives.” We strive to achieve this by focusing on the challenges of current markets, the global environment, and by using the transformative power of artificial intelligence (AI) in business. SAP combines generative AI with business data. We are committed to providing AI solutions that are integral to our', '- We started to develop a carbon footprint sizing approach with the aim of enabling our customers to gain transparency on the carbon impact of their SAP applications that run in SAP’s internal and external data centers, answering the question of how much our customers can reduce their environmental footprint while running SAP solutions on SAP’s self-operated or on SAP sourced infrastructure.'], reference_contexts=None, response="SAP can leverage generative AI to enhance its sustainability solutions by embedding AI capabilities across its portfolio, enabling customers to systematica ...
# <class 'list'>
# <class 'ragas.dataset_schema.SingleTurnSample'>
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__repr__', '__repr_args__', '__repr_name__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_check_frozen', '_copy_and_set_values', '_get_value', '_iter', 'construct', 'copy', 'dict', 'from_orm', 'get_features', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'multi_responses', 'parse_file', 'parse_obj', 'parse_raw', 'reference', 'reference_contexts', 'response', 'retrieved_contexts', 'rubrics', 'schema', 'schema_json', 'to_dict', 'to_string', 'update_forward_refs', 'user_input', 'validate']

# %%
evaluator_llm = LangchainLLMWrapper(llm)

metrics = [
    FactualCorrectness(llm=evaluator_llm, mode="precision", name="FactualCorrectness_Precision"),
    FactualCorrectness(llm=evaluator_llm, mode="recall", name="FactualCorrectness_Recall"),
    FactualCorrectness(llm=evaluator_llm, mode="f1", name="FactualCorrectness_F1"),
    #Faithfulness(llm=evaluator_llm), 
]
results = evaluate(dataset=evaluation_dataset, metrics=metrics)
df_rag = results.to_pandas()
# Out:
# Evaluating: 100%|██████████| 102/102 [04:04<00:00,  2.40s/it]

# %% [markdown]
# # Results

# %%
pd.set_option('display.max_colwidth', 50) # default is 50 / None for unlimited

df_rag

# context recall = measures how many of the relevant documents (or pieces of information) were successfully retrieved
# factual correctness (precision) = proportion of correct claims made that also found in the reference / how many are correct 
# factual correctness (recall) = proportion of facts in the reference that are also present in the response / how many are found
# faithfulness = are the claims made in the response supported by the retrieved context
# semantic similarity = how similar the response is to the ground truth
# Out:
#                                            user_input  \
# 0   How can SAP leverage generative AI to enhance ...
# 1   Considering the increasing importance of ESG f...
# 2   Given the rapid advancements in AI, how can SA...
# 3   How can SAP utilize AI to optimize its global ...
# 4   In what ways can SAP leverage AI to enhance it...
# 5   Considering the potential risks associated wit...
# 6   How can SAP leverage AI to improve its risk ma...
# 7   How can SAP utilize AI to enhance its sales an...
# 8   How can SAP leverage AI to improve its talent ...
# 9   How can SAP utilize AI to enhance its product ...
# 10  Considering the growing importance of sustaina...
# 11  How can SAP utilize AI to improve its financia...
# 12  How can SAP utilize AI to improve its internal...
# 13  Considering the potential for AI to disrupt va...
# 14  How can SAP utilize AI to improve its customer...
# 15  How can SAP leverage AI to improve its operati...
# 16  How can SAP utilize AI to improve its decision...
# 17  How can SAP leverage its technology and expert...
# 18  How can SAP utilize AI to improve its financia...
# 19  How can SAP utilize AI to improve its internal...
# 20  How can SAP utilize AI to improve its product ...
# 21  How can SAP utilize AI to improve its supply c...
# 22  How can SAP leverage its technology and expert...
# 23  How can SAP utilize AI to improve its marketin...
# 24  How can SAP utilize AI to improve its product ...
# 25  How can SAP utilize AI to improve its customer...
# 26  How can SAP utilize AI to improve its internal...
# 27  How can SAP leverage its technology and expert...
# 28  How can SAP utilize AI to improve its risk man...
# 29  How can SAP utilize AI to improve its financia...
# 30  How can SAP utilize AI to improve its internal...
# 31  How can SAP utilize AI to improve its product ...
# 32  How can SAP utilize AI to improve its supply c...
# 33  How can SAP leverage its technology and expert...
#
#                                    retrieved_contexts  \
# 0   [SAP has been an early adopter of AI technolog...
# 1   [in two different ways: by offering solutions ...
# 2   [SAP has been an early adopter of AI technolog...
# 3   [To address new and critical environmental, ec...
# 4   [SAP Business AI refers to artificial intellig...
# 5   [In addition, our Global AI Ethics Policy help...
# 6   [To address new and critical environmental, ec...
# 7   [SAP Business AI refers to artificial intellig...
# 8   [- Build SAP’s Skills for the Future by attrac...
# 9   [SAP has been an early adopter of AI technolog...
# 10  [Due to the comprehensive strategic importance...
# 11  [SAP has been an early adopter of AI technolog...
# 12  [SAP has been an early adopter of AI technolog...
# 13  [To further drive the aforementioned opportuni...
# 14  [To address new and critical environmental, ec...
# 15  [SAP Business AI refers to artificial intellig...
# 16  [One of the main focuses of our discussions wi...
# 17  [SAP recognizes the interdependencies between ...
# 18  [SAP has been an early adopter of AI technolog...
# 19  [One of the main focuses of our discussions wi...
# 20  [implementation of SAP’s enterprise AI strateg...
# 21  [To address new and critical environmental, ec...
# 22  [For over a decade now, climate action has bee...
# 23  [SAP Business AI refers to artificial intellig...
# 24  [SAP has been an early adopter of AI technolog...
# 25  [and IT. By using these AI capabilities, custo...
# 26  [SAP Business AI refers to artificial intellig...
# 27  [SAP recognizes the interdependencies between ...
# 28  [To address new and critical environmental, ec...
# 29  [SAP has been an early adopter of AI technolog...
# 30  [One of the main focuses of our discussions wi...
# 31  [implementation of SAP’s enterprise AI strateg...
# 32  [To address new and critical environmental, ec...
# 33  [For over a decade now, climate action has bee...
#
#                                              response  \
# 0   SAP can leverage generative AI to enhance its ...
# 1   SAP can integrate sustainable practices by opt...
# 2   SAP can strategically invest in research and d...
# 3   SAP can utilize AI to optimize its global supp...
# 4   SAP can leverage AI to enhance customer experi...
# 5   SAP can develop and implement ethical guidelin...
# 6   SAP can leverage AI to enhance its risk manage...
# 7   SAP can enhance its sales and marketing effort...
# 8   SAP can leverage AI to enhance its talent acqu...
# 9   SAP can enhance its product development proces...
# 10  SAP can leverage its technology and expertise ...
# 11  SAP can enhance its financial forecasting and ...
# 12  SAP can utilize AI to enhance internal communi...
# 13  SAP can proactively adapt its business model b...
# 14  SAP can utilize AI to enhance customer support...
# 15  SAP can leverage AI to enhance operational eff...
# 16  SAP can utilize AI to enhance decision-making ...
# 17  SAP can leverage its technology and expertise ...
# 18  SAP can enhance its financial reporting and tr...
# 19  SAP can utilize AI to enhance its internal aud...
# 20  SAP can utilize AI to enhance product pricing ...
# 21  SAP can enhance supply chain resilience by emb...
# 22  SAP can leverage its technology and expertise ...
# 23  SAP can utilize AI to enhance marketing and sa...
# 24  SAP can utilize AI to enhance its product deve...
# 25  SAP can utilize AI to enhance customer experie...
# 26  SAP can utilize AI to enhance internal process...
# 27  SAP can leverage its technology and expertise ...
# 28  SAP can utilize AI to enhance its risk managem...
# 29  SAP can enhance its financial reporting and tr...
# 30  SAP can utilize AI to enhance its internal aud...
# 31  SAP can utilize AI to enhance product pricing ...
# 32  SAP can enhance supply chain resilience by emb...
# 33  SAP can leverage its technology and expertise ...
#
#                                             reference  \
# 0   SAP can leverage generative AI to significantl...
# 1   To minimize its environmental impact and enhan...
# 2   To maintain its leadership and expand into bus...
# 3   SAP can leverage AI to optimize its global sup...
# 4   SAP can leverage AI in several ways to enhance...
# 5   To develop and implement responsible AI at SAP...
# 6   SAP can leverage AI to bolster its risk manage...
# 7   SAP can leverage AI, particularly generative A...
# 8   SAP can leverage AI in several ways to enhance...
# 9   SAP can leverage AI, particularly generative A...
# 10  SAP can leverage its technology and expertise ...
# 11  SAP can leverage AI, particularly generative A...
# 12  SAP can leverage AI to significantly enhance i...
# 13  To remain competitive and capitalize on emergi...
# 14  SAP can leverage AI, particularly generative A...
# 15  SAP can leverage AI, particularly generative A...
# 16  SAP can leverage AI to enhance decision-making...
# 17  SAP can leverage its technology and expertise ...
# 18  SAP can leverage AI to significantly enhance i...
# 19  SAP can leverage AI to significantly enhance i...
# 20  SAP can leverage AI, particularly generative A...
# 21  SAP can leverage AI to bolster its supply chai...
# 22  SAP can leverage its technology and expertise ...
# 23  SAP can leverage AI, particularly generative A...
# 24  SAP can leverage AI, particularly generative A...
# 25  SAP can leverage AI to significantly enhance c...
# 26  SAP can leverage AI to significantly improve i...
# 27  SAP can leverage its technology and expertise ...
# 28  SAP can leverage AI to significantly enhance i...
# 29  SAP can leverage AI to significantly enhance i...
# 30  SAP can leverage AI to significantly enhance i...
# 31  SAP can leverage AI, particularly generative A...
# 32  SAP can leverage AI to bolster its supply chai...
# 33  SAP can leverage its technology and expertise ...
#
#     FactualCorrectness_Precision  FactualCorrectness_Recall  \
# 0                           0.50                       0.17
# 1                           0.29                       0.08
# 2                           0.57                       0.22
# 3                           0.50                       0.28
# 4                           0.64                       0.28
# 5                           0.29                       0.10
# 6                           0.50                       0.24
# 7                           0.50                       0.13
# 8                           0.50                       0.17
# 9                           0.67                       0.17
# 10                          0.80                       0.27
# 11                          0.50                       0.13
# 12                          0.22                       0.10
# 13                          0.75                       0.20
# 14                          0.70                       0.15
# 15                          0.11                       0.04
# 16                          0.57                       0.33
# 17                          0.17                       0.21
# 18                          0.83                       0.22
# 19                          0.50                       0.17
# 20                          1.00                       0.35
# 21                          0.67                       0.27
# 22                          0.70                       0.24
# 23                          0.54                       0.32
# 24                          0.92                       0.52
# 25                          0.58                       0.21
# 26                          0.64                       0.20
# 27                          0.82                       0.31
# 28                          0.44                       0.12
# 29                          0.83                       0.17
# 30                          0.80                       0.35
# 31                          0.56                       0.31
# 32                          0.83                       0.29
# 33                          0.90                       0.27
#
#     FactualCorrectness_F1
# 0                    0.15
# 1                    0.10
# 2                    0.31
# 3                    0.34
# 4                    0.37
# 5                    0.08
# 6                    0.31
# 7                    0.00
# 8                    0.27
# 9                    0.00
# 10                   0.38
# 11                   0.19
# 12                   0.14
# 13                   0.30
# 14                   0.34
# 15                   0.05
# 16                   0.33
# 17                   0.12
# 18                   0.29
# 19                   0.30
# 20                   0.52
# 21                   0.62
# 22                   0.32
# 23                   0.44
# 24                   0.52
# 25                   0.29
# 26                   0.29
# 27                   0.55
# 28                   0.14
# 29                   0.75
# 30                   0.44
# 31                   0.56
# 32                   0.56
# 33                   0.43

# %%
average_metrics = df_rag[['FactualCorrectness_Precision', 'FactualCorrectness_Recall', 'FactualCorrectness_F1']].mean().round(4)

print("Average for each metric:")
print(average_metrics)
# Out:
# Average for each metric:
# FactualCorrectness_Precision    0.5982
# FactualCorrectness_Recall       0.2232
# FactualCorrectness_F1           0.3176
# dtype: float64

# %% [markdown]
# # GraphRAG

# %% [markdown]
# ## Indexing

# %%
# graphrag initial setup
# !mkdir ./graphrag_big_context
# !mkdir ./input_big_context
# !python -m graphrag init --root ./graphrag_big_context
# Out:
# The syntax of the command is incorrect.
# The syntax of the command is incorrect.
# ⠋ GraphRAG Indexer
# Initializing project at
# E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context
# ⠋ GraphRAG Indexer
# ┌───────────────────── Traceback (most recent call last) ─────────────────────┐
# │ e:\Repositories\graphrag-businessqa-evaluation\.conda\Lib\site-packages\gra │
# │ phrag\cli\main.py:105 in _initialize_cli                                    │
# │                                                                             │
# │   102 │   """Generate a default configuration file."""                      │
# │   103 │   from graphrag.cli.initialize import initialize_project_at         │
# │   104 │                                                                     │
# │ > 105 │   initialize_project_at(path=root)                                  │
# │   106                                                                       │
# │   107                                                                       │
# │   108 @app.command("index")                                                 │
# │                                                                             │
# │ ┌──────────────────────────────── locals ─────────────────────────────────┐ │
# │ │ root = WindowsPath('E:/Repositories/graphrag-businessqa-evaluation/gra… │ │
# │ └─────────────────────────────────────────────────────────────────────────┘ │
# │                                                                             │
# │ e:\Repositories\graphrag-businessqa-evaluation\.conda\Lib\site-packages\gra │
# │ phrag\cli\initialize.py:40 in initialize_project_at                         │
# │                                                                             │
# │   37 │   settings_yaml = root / "settings.yaml"                             │
# │   38 │   if settings_yaml.exists():                                         │
# │   39 │   │   msg = f"Project already initialized at {root}"                 │
# │ > 40 │   │   raise ValueError(msg)                                          │
# │   41 │                                                                      │
# │   42 │   with settings_yaml.open("wb") as file:                             │
# │   43 │   │   file.write(INIT_YAML.encode(encoding="utf-8", errors="strict") │
# │                                                                             │
# │ ┌──────────────────────────────── locals ─────────────────────────────────┐ │
# │ │               msg = 'Project already initialized at                     │ │
# │ │                     E:\\Repositories\\graphrag-businessqa-evaluation\\… │ │
# │ │              path = WindowsPath('E:/Repositories/graphrag-businessqa-e… │ │
# │ │ progress_reporter = <graphrag.logging.rich_progress.RichProgressReport… │ │
# │ │                     object at 0x000001EA656304D0>                       │ │
# │ │              root = WindowsPath('E:/Repositories/graphrag-businessqa-e… │ │
# │ │     settings_yaml = WindowsPath('E:/Repositories/graphrag-businessqa-e… │ │
# │ └─────────────────────────────────────────────────────────────────────────┘ │
# └─────────────────────────────────────────────────────────────────────────────┘
# ValueError: Project already initialized at
# E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context

# %%
# indexing, only run once unless you want to update the index
# !python -m graphrag index --root ./graphrag_big_context
# Out:
# ⠋ GraphRAG Indexer
# Logging enabled at
# E:\Repositories\graphrag-businessqa-evaluation\graphrag_big_context\logs\indexi
# ng-engine.log
# ⠋ GraphRAG Indexer
# ⠋ GraphRAG Indexer
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# └── create_base_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# └── create_base_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# └── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# └── create_base_text_units
# 🚀 create_base_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# └── create_base_text_units
# Empty DataFrame
# Columns: []
# Index: []
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# └── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_final_documents
# 🚀 create_final_documents
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_final_documents
#                                  id  ...
# text_unit_ids
# 0  1a08bc23f62c876156bd488dc7331b8c  ...  [322da83b7d764d34811a2518c324c2c3,
# 8a5430b2b72...
# 1  3f2e20baf1cae292da06f1945df584c8  ...  [b26aa7382d3735fcb243bb6735d9cedd,
# 636240fb4e0...
# 2  8d962fdf77351ece7f7295db183ba756  ...  [83f3e8b3925eb4a70fc133652cfe9840,
# 3971a7bbfc6...
# 3  7b473b2b84ed01e6662d258c0bb464ac  ...  [259728c57fcd2f2241475eda7a39559f,
# 5e1d13ad026...
#
# [4 rows x 5 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_final_documents
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# └── create_final_documents
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:02
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:03
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:04
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:05
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:06
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:07
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:08
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:09
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:10
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:11
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:12
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:13
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:14
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:15
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:16
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:17
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:18
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:19
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:20
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:21
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:22
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:23
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:24
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:25
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:26
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:27
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:28
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:29
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:30
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:31
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:32
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:33
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:34
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:35
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:36
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:37
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:38
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:39
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:40
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:41
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:42
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:43
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:44
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:45
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:46
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:47
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:48
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:49
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:50
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:51
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:52
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:53
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:54
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:55
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:56
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:57
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:58
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:00:59
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:01:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:01:01
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   0% -:--:-- 0:01:01
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:02:03 0:01:02
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:02:03 0:01:02
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:02:03 0:01:03
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:02:03 0:01:04
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:02:03 0:01:05
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:02:03 0:01:06
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:02:03 0:01:07
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:13:10 0:01:08
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   1% 0:13:10 0:01:08
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   2% 0:10:16 0:01:09
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --------------------   2% 0:07:50 0:01:09
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   3% 0:05:19 0:01:09
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   4% 0:04:01 0:01:09
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   4% 0:03:12 0:01:09
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   5% 0:03:15 0:01:10
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   5% 0:03:15 0:01:10
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph  -------------------   5% 0:03:15 0:01:11
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:03:28 0:01:12
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:03:28 0:01:12
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:03:28 0:01:13
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:03:28 0:01:14
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:03:28 0:01:15
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:16
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:16
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:17
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:18
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:19
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:20
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:21
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:22
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   5% 0:04:26 0:01:24
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:06:36 0:01:24
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:06:36 0:01:25
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:06:36 0:01:26
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:06:36 0:01:27
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:06:36 0:01:28
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:07:02 0:01:28
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:07:02 0:01:29
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   6% 0:07:02 0:01:30
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:07:02 0:01:30
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:07:02 0:01:31
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:07:02 0:01:32
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:33 0:01:32
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:33 0:01:33
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:33 0:01:34
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:34
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:35
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:36
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:37
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:38
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:39
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:40
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   7% 0:06:38 0:01:41
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:16:30 0:01:41
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:16:30 0:01:42
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:14:45 0:01:42
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:14:45 0:01:43
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:14:45 0:01:44
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:14:45 0:01:45
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   8% 0:14:45 0:01:46
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:12:00 0:01:46
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:12:00 0:01:47
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:10:56 0:01:47
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:09:52 0:01:47
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:09:52 0:01:48
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------   9% 0:09:52 0:01:49
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:09:35 0:01:49
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:09:35 0:01:50
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph - ------------------  10% 0:09:35 0:01:51
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  10% 0:09:28 0:01:52
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  10% 0:09:28 0:01:52
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  10% 0:09:28 0:01:53
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  10% 0:09:28 0:01:54
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:01:54
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:01:55
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:01:56
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:01:57
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:01:58
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:01:59
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:02:00
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:02:01
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:02:02
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:09:22 0:02:03
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:12:21 0:02:04
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:12:21 0:02:04
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:12:21 0:02:05
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:12:21 0:02:06
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:10:28 0:02:06
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  11% 0:10:28 0:02:07
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  12% 0:10:03 0:02:08
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  12% 0:10:03 0:02:08
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  12% 0:10:03 0:02:09
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  12% 0:10:03 0:02:10
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  12% 0:09:56 0:02:10
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:16 0:02:11
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:16 0:02:11
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:16 0:02:12
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:16 0:02:13
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:08 0:02:13
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:08 0:02:14
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:08 0:02:15
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:08 0:02:16
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  13% 0:09:56 0:02:17
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  14% 0:08:24 0:02:17
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  14% 0:08:24 0:02:17
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph -- -----------------  15% 0:08:31 0:02:17
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  15% 0:07:18 0:02:18
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  16% 0:06:51 0:02:18
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
#     └── Verb create_base_entity_graph --- ----------------  16% 0:06:51 0:02:18
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# └── create_base_entity_graph
# ...
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
#                                        id  human_readable_id  ...      period
# size
# 0    108b965f-7308-402a-8e42-2d05858428b6                130  ...  2024-12-22
# 2.0
# 1    2bcbfb8a-0f91-42b1-b650-856cf2c73d16                131  ...  2024-12-22
# 7.0
# 2    22d12e4b-2ddd-4c90-afe6-13adf7f7414e                132  ...  2024-12-22
# 8.0
# 3    44905156-5f11-484b-a3a0-79b8901da974                129  ...  2024-12-22
# 333.0
# 4    87d58ba6-a532-4eee-86d7-03c1ca0dc363                102  ...  2024-12-22
# 2.0
# ..                                    ...                ...  ...         ...
# ...
# 119  6f9aa6ac-30eb-4a58-915e-453930ddadad                  0  ...  2024-12-22
# 391.0
# 120  5e4ac5c0-952b-43f7-8b71-a6042005aade                  1  ...  2024-12-22
# 166.0
# 121  11ec5b9c-debf-4be9-a47e-2587fe87b5c2                  8  ...  2024-12-22
# 65.0
# 122  08634eff-5663-491a-8cb3-a70fdf829bcf                 11  ...  2024-12-22
# 150.0
# 123  b1024f67-7920-498f-9e7b-db160a2b9804                 -1  ...         NaN
# NaN
#
# [124 rows x 13 columns]
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# └── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
#     └── Verb generate_text_embeddings --------------------   0% -:--:-- 0:00:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
#     └── Verb generate_text_embeddings --------------------   0% -:--:-- 0:00:01
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
#     └── Verb generate_text_embeddings -- -----------------  11% -:--:-- 0:00:01
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
#     └── Verb generate_text_embeddings ---- ---------------  22% 0:00:03 0:00:01
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
#     └── Verb generate_text_embeddings ----------- --------  56% 0:00:01 0:00:02
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# 🚀 generate_text_embeddings
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# Empty DataFrame
# Columns: []
# Index: []
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 4 files loaded (4 filtered) - 100%  0…
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# 🚀 All workflows completed successfully.

# %% [markdown]
# ## Query Engine

# %% [markdown]
# ### Global Search
#
# follows the implementations guide by the docs https://microsoft.github.io/graphrag/examples_notebooks/global_search/

# %%
from graphrag_utils import setup_graphrag
import pandas as pd
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.typing import OpenaiApiType
import os
import json
import asyncio

api_key = os.environ["GRAPHRAG_API_KEY"]

llm = ChatOpenAI(
    api_key=api_key,
    model="gpt-4o-mini",
    api_type=OpenaiApiType.OpenAI,
    max_retries=3,
)
community_level = 1

with open(DATASET, 'r') as file:
    data = json.load(file)
    
queries = [response['question'] for response in data['responses']]
references = [response['ground_truth'] for response in data['responses']]

search_engine_global = setup_graphrag(model_name, llm, community_level)

async def perform_global_search(query):
    print(f"Performing search with query: {query}")
    result = await search_engine_global.asearch(query)
    print(f"Result for query: {query} is: {result.response}")
    return result.response

async def run_queries_sequentially(queries, references):
    evaluation_samples = []
    for i, (query, reference) in enumerate(zip(queries, references)):
        result = await perform_global_search(query)
        sample = SingleTurnSample(
            user_input=query,
            response=result,
            reference=reference
        )
        evaluation_samples.append(sample)

        # delay for 90 seconds to avoid rate limiting / token limit
        if i < len(queries) - 1:
            await asyncio.sleep(60)

    return evaluation_samples

evaluation_samples = await run_queries_sequentially(queries, references)

evaluation_dataset = EvaluationDataset(samples=evaluation_samples)
# Out:
# Missing reports for communities: [43, 12, 23, 4, 11, 42, 2, 25, 14, 26, 27, 29, 18, 38, 15, 32, 1, 36, 31, 39, 22, 28, 13, 37, 30, 16, 47, 6, 44, 49, 7, 48, 24, 35, 20, 45, 50, 41, 33, 19, 40, 379, 364, 246, 80, 161, 144, 169, 362, 149, 280, 403, 365, 293, 342, 130, 184, 370, 369, 338, 124, 133, 353, 129, 366, 317, 381, 383, 314, 358, 132, 110, 304, 274, 399, 345, 230, 347, 315, 312, 350, 275, 346, 322, 325, 343, 302, 352, 348, 397, 400, 354, 367, 308, 269, 281, 290, 284, 286, 303, 331, 291, 289, 277, 320, 299, 283, 298, 297, 300, 301, 413, 382, 251, 318, 412, 282, 295, 285, 378, 296, 416, 363, 360, 387, 173, 385, 390, 388, 386, 392, 418, 407, 361, 408, 406, 270, 417, 398, 377, 404, 307, 334, 368, 309, 376, 336, 375, 356, 419, 310, 339, 344, 384, 372, 337, 401, 405, 159, 330, 335, 332, 333, 340, 311, 306, 329, 394, 328, 359, 323, 414, 409, 410, 393, 287, 411, 389, 374, 324, 326, 327, 396, 279, 355, 402, 305, 288, 415, 634, 628, 456, 765, 650, 469, 573, 776, 683, 529, 509, 884, 541, 840, 665, 789, 696, 858, 928, 867, 873, 812, 612, 582, 743, 570, 477, 687, 817]
#                                      id  human_readable_id  community  level  \
# 0  eb3dcb87-2f35-41f6-acd4-ab9b2b0ddefe               1071       1071      4
# 1  3c26ae78-a0fe-4aba-a560-fb6423582011               1072       1072      4
# 2  81cb72d7-a386-4cf3-8d1f-c8935e6fc1cf               1073       1073      4
# 3  b45e85bf-2ddc-4d70-b911-0c9eb360f9b2               1074       1074      4
# 4  fdf8ff70-2451-4c40-9336-c115ca1e646f               1075       1075      4
#
#                                                title  \
# 0      Corporate Environmental Performance Community
# 1           A. M. Romi and Kelley School of Business
# 2  Corporate Social Responsibility Research Commu...
# 3     Cowen et al. and Correlation Studies Community
# 4           Panel B and Emissions Analysis Community
#
#                                              summary  \
# 0  The community focuses on Corporate Environment...
# 1  The community centers around A. M. Romi, an au...
# 2  This community is centered around influential ...
# 3  This community is centered around the research...
# 4  The community centers around Panel B, which pr...
#
#                                         full_content  rank  \
# 0  # Corporate Environmental Performance Communit...   7.5
# 1  # A. M. Romi and Kelley School of Business\n\n...   4.0
# 2  # Corporate Social Responsibility Research Com...   7.5
# 3  # Cowen et al. and Correlation Studies Communi...   6.5
# 4  # Panel B and Emissions Analysis Community\n\n...   7.5
#
#                                     rank_explanation  \
# 0  The impact severity rating is high due to the ...
# 1  The impact severity rating is moderate due to ...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is moderate to high...
# 4  The impact severity rating is high due to the ...
#
#                                             findings  \
# 0  [{'explanation': 'Corporate Environmental Perf...
# 1  [{'explanation': 'A. M. Romi is a key figure i...
# 2  [{'explanation': 'Orlitzky et al. are pivotal ...
# 3  [{'explanation': 'Cowen et al. are recognized ...
# 4  [{'explanation': 'Panel B serves as the core e...
#
#                                    full_content_json      period  size
# 0  {\n    "title": "Corporate Environmental Perfo...  2024-12-20  19.0
# 1  {\n    "title": "A. M. Romi and Kelley School ...  2024-12-20   2.0
# 2  {\n    "title": "Corporate Social Responsibili...  2024-12-20  11.0
# 3  {\n    "title": "Cowen et al. and Correlation ...  2024-12-20   2.0
# 4  {\n    "title": "Panel B and Emissions Analysi...  2024-12-20  19.0
# Performing search with query: How can SAP leverage generative AI to enhance its sustainability solutions, enabling customers to more effectively track and reduce their carbon footprints while simultaneously improving the efficiency of their internal processes?
# Result for query: How can SAP leverage generative AI to enhance its sustainability solutions, enabling customers to more effectively track and reduce their carbon footprints while simultaneously improving the efficiency of their internal processes? is: ## Leveraging Generative AI for Enhanced Sustainability Solutions
#
# SAP has a significant opportunity to leverage generative AI in its sustainability solutions, which can empower customers to effectively track and reduce their carbon footprints while enhancing the efficiency of internal processes. The integration of generative AI can facilitate a comprehensive approach to sustainability management, focusing on data analysis, automation, and real-time monitoring.
#
# ### Data-Driven Insights and Reporting
#
# Generative AI can analyze vast amounts of data related to carbon emissions, enabling customers to gain valuable insights into their carbon footprints. This data-driven approach will enhance the accuracy of sustainability reporting, allowing organizations to set realistic and effective carbon reduction targets [Data: Reports (152, 243, 261, 235, 140)]. By automating the tracking of emissions across various business processes, SAP may improve operational efficiency and reduce the manual effort required for data collection and analysis [Data: Reports (272, 261, 235, 140)].
#
# ### Automation and Efficiency
#
# The integration of generative AI into SAP's sustainability solutions may streamline internal processes through automation. This capability can reduce the time and resources required for sustainability assessments and reporting, allowing organizations to focus on strategic initiatives [Data: Reports (60, 170, 233, 357)]. Furthermore, generative AI can facilitate predictive analytics, enabling customers to forecast future carbon emissions based on current data trends. This proactive approach will help organizations implement measures to reduce their carbon footprints before they exceed targets [Data: Reports (152, 243, 261, 235, 140)].
#
# ### Real-Time Monitoring and Continuous Improvement
#
# Generative AI can support real-time monitoring of carbon emissions, allowing organizations to track their progress towards sustainability goals more effectively. This capability can lead to timely adjustments in strategies and operations, ensuring continuous improvement in sustainability performance [Data: Reports (245, 60, 170, 233, 357)]. Additionally, the development of customized dashboards can provide real-time visibility into carbon emissions and sustainability metrics, empowering customers to make informed decisions and track their progress effectively [Data: Reports (217, 139, 100, 185, 206, +more)].
#
# ### Scenario Modeling and Strategic Decision-Making
#
# Generative AI can facilitate scenario modeling, allowing SAP's customers to simulate the impact of various sustainability initiatives on their carbon footprints. This predictive capability will enable organizations to make informed decisions about which strategies to implement for maximum impact [Data: Reports (183, 221, 97, 68, 204, +more)]. By providing a platform for sharing best practices and insights, SAP can foster collaboration among stakeholders, driving collective action towards carbon reduction goals [Data: Reports (125, 168, 126, 120, 72, +more)].
#
# ### Conclusion
#
# In summary, SAP's integration of generative AI into its sustainability solutions shall enhance the ability of customers to track and reduce their carbon footprints while simultaneously improving internal process efficiency. By leveraging data-driven insights, automation, real-time monitoring, and scenario modeling, SAP can empower organizations to make informed decisions and achieve their sustainability objectives more effectively. This strategic approach not only supports environmental goals but also enhances operational efficiency, ultimately driving better business performance.
# Performing search with query: Considering the increasing importance of ESG factors, how can SAP integrate sustainable practices into its core business operations, including its data centers and supply chain, to minimize its environmental impact and enhance its brand reputation?
# Result for query: Considering the increasing importance of ESG factors, how can SAP integrate sustainable practices into its core business operations, including its data centers and supply chain, to minimize its environmental impact and enhance its brand reputation? is: ## Integrating Sustainable Practices at SAP
#
# As the significance of Environmental, Social, and Governance (ESG) factors continues to rise, SAP has a unique opportunity to enhance its brand reputation and minimize its environmental impact by integrating sustainable practices into its core business operations. This integration can be achieved through various strategies focused on its data centers and supply chain.
#
# ### Enhancing Data Center Sustainability
#
# SAP can significantly improve the sustainability of its data centers by adopting energy-efficient technologies and practices. This includes optimizing server utilization, implementing advanced cooling systems, and utilizing renewable energy sources to power operations. Research indicates that companies prioritizing energy efficiency in their data centers can reduce carbon emissions and operational costs, which aligns with broader sustainability goals [Data: Reports (61, 71, 276, 254, 197, +more)].
#
# Moreover, SAP may consider implementing eco-efficiency strategies that focus on resource optimization and minimizing energy consumption. This approach not only aligns with sustainability reporting principles but also enhances transparency and accountability in environmental performance [Data: Reports (235, 243, 261, 272, 140, +more)].
#
# ### Sustainable Supply Chain Management
#
# In its supply chain, SAP can adopt sustainable supplier selection practices by evaluating suppliers based on their environmental performance and sustainability criteria. This practice reinforces responsible sourcing and aligns with global sustainability goals, thereby enhancing SAP's overall sustainability performance and brand image [Data: Reports (232, 267, 109, 138, 81)].
#
# Additionally, integrating sustainability criteria into the supplier selection process is crucial for ensuring that supply chain partners adhere to environmental standards. This collaboration can improve stakeholder trust and potentially lead to better financial outcomes, as firms with strong CSR practices tend to achieve better financial results [Data: Reports (235, 243, 261, 272, 140, +more)].
#
# ### Corporate Social Responsibility (CSR) Initiatives
#
# SAP may also enhance its brand reputation by actively engaging in CSR initiatives that align with ESG factors. This includes community projects focused on environmental conservation and education, which demonstrate SAP's commitment to sustainability beyond its operations [Data: Reports (211, 263, 197, 276, 142, +more)]. Engaging in transparent CSR reporting will further enhance stakeholder trust and showcase SAP's dedication to sustainable practices [Data: Reports (60, 170, 134)].
#
# ### Leveraging Technological Capabilities
#
# SAP can leverage its technological capabilities to develop solutions that assist clients in tracking and managing their own ESG performance. By providing tools for sustainability reporting and compliance, SAP can position itself as a leader in corporate responsibility, thereby enhancing its brand reputation [Data: Reports (57, 61, 211, 197, 276, +more)].
#
# ### Conclusion
#
# In conclusion, SAP has the potential to integrate sustainable practices into its core business operations effectively. By focusing on energy-efficient data centers, sustainable supply chain management, proactive CSR initiatives, and leveraging technology, SAP can minimize its environmental impact while enhancing its brand reputation. These strategies not only align with the growing emphasis on ESG factors but also position SAP as a responsible corporate entity in the market.
# Performing search with query: Given the rapid advancements in AI, how can SAP strategically invest in research and development to maintain its leadership position in enterprise applications while simultaneously expanding its capabilities in business AI and generative AI?
# Result for query: Given the rapid advancements in AI, how can SAP strategically invest in research and development to maintain its leadership position in enterprise applications while simultaneously expanding its capabilities in business AI and generative AI? is: To maintain its leadership position in enterprise applications while expanding capabilities in business AI and generative AI, SAP should adopt a multifaceted strategy focused on research and development (R&D) investments. This strategy should encompass the integration of advanced AI technologies into existing applications, fostering partnerships, and enhancing internal capabilities.
#
# ### Integration of AI Technologies
#
# SAP should prioritize the integration of AI capabilities into its existing enterprise applications. This includes developing features such as predictive analytics, automated decision-making, and generative AI functionalities that can enhance user experience and operational efficiency. By investing in R&D that explores these AI-driven features, SAP can ensure that its products remain competitive and relevant in the rapidly evolving tech landscape [Data: Reports (125, 168, 126, 128, 120, +more); (240, 194, 141, 264, 244, +more); (1, 2, 3, 4, 5, +more)].
#
# ### Strategic Partnerships
#
# Investing in partnerships with leading AI research institutions and technology companies will facilitate knowledge exchange and accelerate innovation. Collaborations can lead to the development of cutting-edge solutions that enhance SAP's product offerings and expand its capabilities in AI. This approach will not only provide access to advanced technologies but also position SAP as a frontrunner in the AI landscape [Data: Reports (125, 168, 126, 128, 120, +more); (6, 7, 8, 9, 10, +more)].
#
# ### Building Internal Expertise
#
# To effectively implement AI solutions, SAP must focus on building a robust internal R&D team dedicated to AI research. This includes continuous investment in talent acquisition and training in AI-related fields, ensuring that the workforce is equipped with the necessary skills to drive innovation. By fostering a culture of experimentation and rapid prototyping, SAP can explore new AI applications and refine its generative AI capabilities [Data: Reports (11, 12, 13, 14, 15, +more); (263, 211, 276, 71, 142)].
#
# ### Establishing Innovation Labs
#
# SAP may consider establishing dedicated innovation labs focused on AI research and development. These labs can serve as incubators for new ideas and technologies, allowing SAP to experiment with generative AI applications that can be integrated into its enterprise solutions. This proactive approach will enable SAP to stay ahead of market trends and customer needs [Data: Reports (125, 168, 126, 128, 120, +more); (197, 263, 211, 276, 71)].
#
# ### Ethical AI Practices
#
# Finally, SAP should prioritize the development of ethical AI frameworks to guide its AI initiatives. By leading in ethical AI practices, SAP can build trust with customers and stakeholders, which is crucial for long-term success in the AI landscape. This focus on ethical considerations will differentiate SAP from competitors and enhance its reputation in the market [Data: Reports (57, 61, 211, 276, 142)].
#
# ### Conclusion
#
# In summary, SAP's strategic investments in R&D should focus on integrating AI technologies into existing applications, fostering strategic partnerships, building internal expertise, establishing innovation labs, and prioritizing ethical AI practices. By adopting this comprehensive approach, SAP can maintain its leadership position in enterprise applications while effectively expanding its capabilities in business AI and generative AI.
# Performing search with query: How can SAP utilize AI to optimize its global supply chain, improving efficiency, reducing costs, and mitigating risks associated with geopolitical instability and climate change impacts?
# Result for query: How can SAP utilize AI to optimize its global supply chain, improving efficiency, reducing costs, and mitigating risks associated with geopolitical instability and climate change impacts? is: # Optimizing SAP's Global Supply Chain with AI
#
# SAP can leverage artificial intelligence (AI) in several key areas to enhance the efficiency of its global supply chain, reduce costs, and mitigate risks associated with geopolitical instability and climate change. The integration of AI technologies will enable SAP to make data-driven decisions that improve operational resilience and sustainability.
#
# ## Enhancing Demand Forecasting
#
# One of the primary applications of AI in SAP's supply chain is enhancing demand forecasting accuracy. By analyzing historical data and real-time market trends, AI algorithms can predict future demand more effectively. This predictive capability allows for better inventory management and reduced holding costs, ultimately leading to optimized stock levels and minimized waste [Data: Reports (152, 243, 261, 235, 140, +more)]. Improved demand forecasting will enable SAP to allocate resources more efficiently and respond more swiftly to market changes, thereby enhancing overall supply chain efficiency [Data: Reports (391, 120, 72, 86, 249, +more)].
#
# ## Risk Management and Mitigation
#
# AI-driven risk management tools can help SAP identify and assess risks related to geopolitical instability and climate change. By continuously monitoring external factors and simulating various scenarios, SAP can develop contingency plans that mitigate potential disruptions in the supply chain [Data: Reports (60, 170, 370, 154, 213)]. This proactive approach will allow SAP to implement measures such as diversifying suppliers or adjusting sourcing strategies to reduce vulnerability to external shocks [Data: Reports (243, 261, 140, 220, 192, +more)].
#
# ## Optimizing Logistics and Transportation
#
# AI can also be utilized to optimize logistics and transportation routes by analyzing real-time data on traffic, weather, and geopolitical conditions. This optimization can lead to reduced transportation costs and improved delivery times, enhancing customer satisfaction and operational efficiency [Data: Reports (272, 261, 243, 140, 220, +more)]. By dynamically adjusting routes to avoid disruptions, SAP can ensure a more resilient supply chain that can adapt to changing conditions [Data: Reports (170, 233, 237, 134, 241)].
#
# ## Supplier Selection and Management
#
# AI can facilitate improved supplier selection and evaluation processes by analyzing supplier performance data, risk factors, and geopolitical conditions. This structured approach ensures that sustainability and risk factors are considered, promoting environmentally responsible sourcing and reducing risks associated with supplier disruptions [Data: Reports (231)]. By identifying reliable suppliers and negotiating better terms, SAP can enhance its supply chain resilience and reduce costs [Data: Reports (391, 120, 72, 86, 249, +more)].
#
# ## Real-Time Monitoring and Agility
#
# Implementing AI for real-time monitoring of supply chain operations will allow SAP to quickly identify and respond to disruptions caused by climate change impacts or geopolitical instability. This agility will enhance resilience and ensure continuity in supply chain processes [Data: Reports (57, 61, 211, 276, 71)]. By providing a centralized platform for data sharing and communication among stakeholders, AI can facilitate enhanced collaboration across the supply chain, leading to improved responsiveness to market changes [Data: Reports (152, 243, 261, 235, 140, +more)].
#
# ## Conclusion
#
# In conclusion, SAP's utilization of AI across various facets of its global supply chain will significantly improve efficiency, reduce costs, and mitigate risks associated with geopolitical instability and climate change. By enhancing demand forecasting, implementing robust risk management strategies, optimizing logistics, improving supplier relationships, and enabling real-time monitoring, SAP can build a more resilient and sustainable supply chain that is well-equipped to navigate the complexities of the modern business environment.
# Performing search with query: In what ways can SAP leverage AI to enhance its customer experience, improving customer loyalty and satisfaction while simultaneously reducing operational costs and increasing efficiency?
# Result for query: In what ways can SAP leverage AI to enhance its customer experience, improving customer loyalty and satisfaction while simultaneously reducing operational costs and increasing efficiency? is: ## Enhancing Customer Experience through AI at SAP
#
# SAP can leverage artificial intelligence (AI) in several impactful ways to enhance customer experience, which in turn may improve customer loyalty and satisfaction while also reducing operational costs and increasing efficiency.
#
# ### Personalized Customer Interactions
#
# AI-driven analytics can provide SAP with deep insights into customer behavior and preferences. By analyzing data from various touchpoints, SAP can tailor its offerings to meet specific customer needs, fostering stronger relationships with clients. This personalization allows for targeted marketing strategies and tailored product recommendations, making customers feel understood and valued [Data: Reports (152, 243, 261, 235, 140, +more)].
#
# ### Implementation of AI Chatbots and Virtual Assistants
#
# The integration of AI chatbots and virtual assistants can significantly streamline customer service operations. These technologies provide real-time support, offering instant responses to customer inquiries and reducing wait times. This not only enhances customer satisfaction but also lowers operational costs by minimizing the need for extensive human customer service resources [Data: Reports (77, 180, 83, 196, 114)]. Furthermore, these AI systems can operate 24/7, ensuring that customers receive timely assistance whenever needed [Data: Reports (78, +more)].
#
# ### Predictive Maintenance and Proactive Support
#
# AI can enhance predictive maintenance for SAP's products, allowing customers to anticipate issues before they arise. This proactive approach can lead to increased customer satisfaction and loyalty, as clients experience fewer disruptions and improved service reliability. By predicting potential issues, SAP can help customers maintain high levels of productivity, which is crucial for fostering trust and long-term relationships [Data: Reports (243, 261, 235, 140, 189, +more)].
#
# ### Enhanced Feedback Mechanisms
#
# AI-driven sentiment analysis can help SAP monitor customer feedback across various channels, enabling proactive engagement with customers. By understanding customer sentiments in real-time, SAP can address issues before they escalate, thereby improving customer satisfaction and loyalty. This feedback loop allows for rapid adjustments to services and products, ensuring that customer needs are met promptly [Data: Reports (125, 168, 126, 128, 120, +more)].
#
# ### Operational Efficiency through Automation
#
# Leveraging AI for process automation can significantly increase operational efficiency within SAP's internal processes. By automating routine tasks, SAP can reduce costs associated with manual processes and allocate resources more effectively. This efficiency gain can be passed on to customers in the form of better pricing or enhanced service offerings, further driving customer loyalty [Data: Reports (60, 170, 371, 151, 154)].
#
# ### Conclusion
#
# In summary, SAP has multiple avenues to enhance customer experience through AI. By focusing on personalized interactions, implementing AI chatbots, utilizing predictive maintenance, enhancing feedback mechanisms, and automating processes, SAP can improve customer loyalty and satisfaction while simultaneously reducing operational costs and increasing efficiency. These strategies not only align with modern corporate practices but also position SAP as a leader in customer-centric solutions [Data: Reports (231, 150, 79, 82, 91)].
# Performing search with query: Considering the potential risks associated with AI, such as bias and data privacy, how can SAP develop and implement ethical guidelines and robust security measures to ensure responsible AI development and deployment?
# Result for query: Considering the potential risks associated with AI, such as bias and data privacy, how can SAP develop and implement ethical guidelines and robust security measures to ensure responsible AI development and deployment? is: # Developing Ethical Guidelines and Robust Security Measures for Responsible AI at SAP
#
# As SAP navigates the complexities of AI development, it is imperative to address potential risks such as bias and data privacy. A comprehensive approach that integrates ethical guidelines and robust security measures will be essential in fostering responsible AI practices.
#
# ## Ethical Guidelines for AI Development
#
# To mitigate risks associated with bias in AI systems, SAP may focus on developing ethical guidelines that emphasize fairness in algorithmic decision-making. This can be achieved by incorporating diverse datasets to ensure representation and minimize bias in AI outcomes. Regular reviews and updates of these guidelines will be crucial to adapt to technological advancements and societal expectations [Data: Reports (152, 243, 261, 235, 52, +more)].
#
# Establishing a comprehensive framework for ethical AI development is also recommended. This framework should include guidelines addressing bias, transparency, and accountability, informed by best practices in corporate social responsibility (CSR) and stakeholder engagement. Engaging with external stakeholders, including academic institutions and industry experts, may enhance SAP's understanding of ethical AI practices and emerging security threats, thereby refining its guidelines [Data: Reports (72, 125, 126, 168, 223, +more)].
#
# ## Robust Security Measures
#
# Implementing robust security measures is crucial for protecting data privacy during AI development. SAP should prioritize encryption techniques, access controls, and regular audits to safeguard sensitive information from unauthorized access and breaches. These measures will not only help in complying with data protection regulations such as GDPR but also in maintaining user trust [Data: Reports (272, 140, 189, 319, 84, +more)].
#
# Integrating security measures into the AI development lifecycle is essential. This includes conducting regular audits and assessments of AI systems to identify and address any biases or security vulnerabilities proactively. Such a proactive approach will ensure that ethical standards and security protocols are upheld throughout the AI lifecycle [Data: Reports (221, 183, 97, 68, 204, +more)].
#
# ## Fostering a Culture of Responsibility
#
# Training and awareness programs for employees on ethical AI practices and data privacy will be vital in fostering a culture of responsibility within SAP. By equipping staff with the necessary knowledge and skills, SAP can promote ethical behavior and adherence to security protocols in AI development. This initiative will empower employees to recognize and address potential ethical dilemmas and security challenges in their work [Data: Reports (243, 261, 235, 52, 140, +more)].
#
# In conclusion, SAP's commitment to responsible AI development hinges on the establishment of ethical guidelines that address bias and transparency, alongside robust security measures to protect data privacy. By fostering a culture of ethical awareness and continuous improvement, SAP can navigate the complexities of AI while ensuring trust and integrity in its applications.
# Performing search with query: How can SAP leverage AI to improve its risk management capabilities, identifying and mitigating potential threats to its business while simultaneously enhancing its resilience to economic downturns and geopolitical instability?
# Result for query: How can SAP leverage AI to improve its risk management capabilities, identifying and mitigating potential threats to its business while simultaneously enhancing its resilience to economic downturns and geopolitical instability? is: # Leveraging AI for Enhanced Risk Management at SAP
#
# SAP can significantly enhance its risk management capabilities by integrating artificial intelligence (AI) into its processes. This integration shall enable the company to identify and mitigate potential threats more effectively while bolstering its resilience against economic downturns and geopolitical instability.
#
# ## Predictive Analytics and Real-Time Monitoring
#
# One of the primary ways SAP may utilize AI is through predictive analytics. By analyzing historical data and trends, AI can identify potential threats before they materialize. This proactive approach allows SAP to implement measures that mitigate risks, thereby improving overall business resilience [Data: Reports (152, 243, 272, 261, 235, +more)]. Furthermore, AI-driven tools can facilitate real-time monitoring of various risk factors, including market fluctuations and geopolitical events. This capability ensures that SAP can respond swiftly to emerging threats, maintaining operational continuity during crises [Data: Reports (316, 188, 58, 101, 239, +more)].
#
# ## Automation of Risk Assessment Processes
#
# AI can also assist in automating risk assessment processes, enabling SAP to analyze vast amounts of data related to market conditions, regulatory changes, and geopolitical events quickly. This automation leads to faster identification of risks and more efficient resource allocation to mitigate those risks, ultimately enhancing SAP's ability to respond to unforeseen challenges [Data: Reports (180, 83, 196, 77, 114)]. By streamlining these processes, SAP can focus its human resources on strategic planning and response efforts, thereby increasing its operational resilience [Data: Reports (140, 189, 319, 85, 122, +more)].
#
# ## Scenario Analysis and Stress Testing
#
# The implementation of AI-driven tools can facilitate scenario analysis and stress testing, allowing SAP to simulate various economic and geopolitical scenarios. This capability enables the company to evaluate its preparedness for different risk situations and develop robust contingency plans, ultimately strengthening its resilience against unforeseen challenges [Data: Reports (238, 292, 240, 373, 187)]. By understanding potential impacts on its operations, SAP can make informed decisions that align with its risk management strategies [Data: Reports (150, 82, 91, 182, 202)].
#
# ## Enhanced Decision-Making and Collaboration
#
# Integrating AI with existing risk management frameworks can provide SAP with deeper insights into interdependencies between different risk factors. This holistic view is essential for comprehensive risk mitigation, as it helps identify compound risks that may arise from simultaneous economic and geopolitical challenges [Data: Reports (183, 221, 97, 68, 204)]. Additionally, AI technologies can improve communication and collaboration across SAP's departments, ensuring that risk management strategies are integrated into all levels of the organization. This fosters a culture of shared responsibility for risk management, enhancing the company's ability to respond effectively to risks [Data: Reports (119, 192, 214, 220, 222, +more)].
#
# ## Conclusion
#
# In conclusion, SAP can leverage AI to enhance its risk management capabilities by implementing predictive analytics, automating risk assessment processes, conducting scenario analysis, and improving decision-making and collaboration across departments. These strategies will not only help identify and mitigate potential threats but also enhance SAP's resilience to economic downturns and geopolitical instability, ensuring the company remains agile and responsive in a rapidly changing environment [Data: Reports (148, 166, 90, 64, 163, +more)].
# Performing search with query: How can SAP utilize AI to enhance its sales and marketing efforts, increasing revenue and market share while simultaneously improving customer engagement and brand loyalty?
# Result for query: How can SAP utilize AI to enhance its sales and marketing efforts, increasing revenue and market share while simultaneously improving customer engagement and brand loyalty? is: ## Enhancing Sales and Marketing with AI
#
# SAP can leverage artificial intelligence (AI) in several strategic ways to enhance its sales and marketing efforts, ultimately increasing revenue and market share while improving customer engagement and brand loyalty.
#
# ### Personalized Marketing Strategies
#
# One of the most significant applications of AI for SAP lies in its ability to analyze customer data and predict buying behaviors. By utilizing AI-driven analytics, SAP can develop personalized marketing strategies that resonate with individual customer preferences. This targeted approach may lead to higher conversion rates and increased sales revenue, as marketing efforts become more aligned with customer needs and expectations [Data: Reports (152, 243, 261, 235, 140, +more)].
#
# ### AI-Driven Customer Engagement
#
# Implementing AI-driven chatbots and virtual assistants can significantly enhance customer engagement. These tools provide 24/7 support, offering instant responses to inquiries and improving overall customer satisfaction. By ensuring that customers feel valued and supported, SAP can foster brand loyalty, encouraging repeat business and long-term relationships [Data: Reports (272, 261, 235, 140, 189, +more)].
#
# ### Optimizing Sales Forecasting
#
# AI can also optimize sales forecasting by analyzing historical sales data and market trends. This capability allows SAP to make informed decisions regarding inventory management and resource allocation, ensuring that product availability aligns with customer demand. Such strategic insights may help SAP capture a larger market share by reducing stockouts and overstock situations [Data: Reports (243, 261, 235, 140, 189, +more)].
#
# ### Dynamic Pricing Strategies
#
# Another critical area where AI can be beneficial is in facilitating dynamic pricing strategies. By analyzing competitor pricing, demand fluctuations, and customer behavior, SAP can adjust prices in real-time to maximize revenue while remaining competitive in the market. This adaptability can lead to increased sales and improved market share, as pricing becomes more responsive to market conditions [Data: Reports (125, 168, 126, 128, 120, +more)].
#
# ### Sentiment Analysis for Brand Perception
#
# Utilizing AI for sentiment analysis on social media and customer feedback can provide SAP with valuable insights into brand perception and customer satisfaction. This information can guide marketing strategies and product development, ultimately enhancing customer engagement and loyalty. By understanding public sentiment, SAP can proactively adjust its marketing efforts to better align with customer expectations [Data: Reports (261, 235, 140, 189, 319, +more)].
#
# ### Conclusion
#
# In summary, SAP has numerous opportunities to utilize AI to enhance its sales and marketing efforts. By focusing on personalized marketing strategies, improving customer engagement through AI-driven support, optimizing sales forecasting, implementing dynamic pricing, and conducting sentiment analysis, SAP can increase revenue and market share while simultaneously fostering customer loyalty. These strategies will not only improve operational efficiency but also create a more responsive and customer-centric business model.
# Performing search with query: How can SAP leverage AI to improve its talent acquisition and development strategies, attracting and retaining top talent while simultaneously fostering a diverse and inclusive workplace?
# Result for query: How can SAP leverage AI to improve its talent acquisition and development strategies, attracting and retaining top talent while simultaneously fostering a diverse and inclusive workplace? is: ## Leveraging AI for Talent Acquisition and Development at SAP
#
# SAP can significantly enhance its talent acquisition and development strategies by implementing AI-driven tools and analytics. These technologies shall not only streamline recruitment processes but also promote diversity and inclusion, ultimately attracting and retaining top talent.
#
# ### Enhancing Recruitment Processes
#
# AI tools can be utilized to detect and mitigate biases in recruitment processes. By analyzing job descriptions and candidate evaluations, AI can identify potentially biased language and suggest more inclusive alternatives. This approach ensures that job postings attract a wider range of candidates, fostering a diverse talent pool [Data: Reports (152, 243, 261, 140, 220, +more)]. Furthermore, AI can analyze candidate data to identify the best fits for job roles based on skills and qualifications rather than demographic factors, thus reducing bias and promoting a more equitable hiring process [Data: Reports (238, 292, 240, 373, 244)].
#
# Additionally, AI-driven analytics can enhance SAP's talent acquisition strategies by identifying the most effective recruitment channels and predicting candidate success based on historical data. This targeted approach allows SAP to attract top talent more efficiently [Data: Reports (125, 168, 126, 128, 223, +more)].
#
# ### Improving Candidate Experience
#
# AI can also enhance the candidate experience by automating initial screening processes and providing personalized communication throughout the recruitment journey. This not only improves efficiency but also ensures that candidates feel valued and engaged, which is crucial for attracting top talent [Data: Reports (125, 168, 126, 128, 223, +more)]. AI-powered chatbots can provide real-time responses to inquiries, guiding candidates through application procedures and improving overall engagement [Data: Reports (148, 166, 90, 64, 163, +more)].
#
# ### Fostering Employee Development
#
# In terms of employee development, AI can facilitate personalized learning and development programs tailored to individual needs and career aspirations. By analyzing performance data and identifying skill gaps, AI can recommend tailored training opportunities that support career growth and enhance employee satisfaction [Data: Reports (125, 168, 126, 128, 223, +more)]. This customization not only aids in employee retention but also fosters a diverse skill set within the workforce, contributing to an inclusive environment [Data: Reports (261, 243, 272, 140, 220, +more)].
#
# Moreover, leveraging AI for continuous feedback mechanisms can enhance performance management by providing real-time insights into employee performance and development needs. This ongoing dialogue supports a culture of inclusivity and growth, ensuring that all employees have the opportunity to succeed and advance within the organization [Data: Reports (78, 267, 109, 81, 138, +more)].
#
# ### Conclusion
#
# By integrating AI into its talent acquisition and development strategies, SAP can create a more efficient, equitable, and inclusive workplace. The use of AI tools for bias detection, personalized learning, and enhanced candidate experiences will not only attract top talent but also ensure that diverse employees feel valued and supported throughout their careers. This strategic approach shall position SAP as a leader in fostering a diverse and inclusive workplace culture, ultimately driving organizational success.
# Performing search with query: How can SAP utilize AI to enhance its product development process, accelerating innovation and improving product quality while simultaneously reducing costs and time to market?
# Result for query: How can SAP utilize AI to enhance its product development process, accelerating innovation and improving product quality while simultaneously reducing costs and time to market? is: ## Enhancing Product Development with AI at SAP
#
# SAP can leverage artificial intelligence (AI) in several strategic ways to enhance its product development process. By integrating AI into various stages of development, SAP may accelerate innovation, improve product quality, and reduce both costs and time to market.
#
# ### Proactive Quality Assurance
#
# Integrating AI into quality assurance processes shall enable SAP to identify defects and issues earlier in the development cycle. This proactive approach to quality management may significantly improve product quality and reduce the costs associated with late-stage corrections [Data: Reports (16, 17, 18, 19, 20, +more)]. By utilizing AI for real-time monitoring and analysis of product performance, SAP can ensure that products meet quality standards before launch, thus minimizing the risk of costly post-launch fixes [Data: Reports (267, 109, 81, 138, 186, +more)].
#
# ### Automation of Development Processes
#
# AI can facilitate automation across various stages of the product development process, including design, testing, and quality assurance. This automation may reduce manual errors, enhance efficiency, and ultimately lower costs and time to market [Data: Reports (11, 12, 13, 14, 15, +more)]. By automating routine tasks such as data entry and analysis, teams can focus on more strategic activities, thereby enhancing overall productivity [Data: Reports (180, 83, 196, 77, 114, +more)].
#
# ### Data-Driven Decision Making
#
# SAP can utilize AI to analyze vast amounts of data from previous product development cycles, identifying patterns and insights that can inform future projects. This data-driven approach may lead to more informed decision-making, enhancing innovation and product quality [Data: Reports (152, 243, 261, 235, 52, +more)]. By implementing AI-driven predictive analytics, SAP can forecast market trends and customer preferences more accurately, allowing for proactive adjustments in product development [Data: Reports (272, 140, 189, 319, 122, +more)].
#
# ### Continuous Feedback Loops
#
# Utilizing AI for continuous feedback loops from customers and stakeholders can help SAP refine its products in real-time. This responsiveness to user feedback may enhance product quality and ensure that developments are aligned with customer needs, thus reducing the risk of costly revisions later in the process [Data: Reports (21, 22, 23, 24, 25, +more)].
#
# ### Accelerating Innovation through Collaboration
#
# AI-powered collaboration tools can enhance communication and knowledge sharing among teams, fostering a culture of innovation. This collaborative environment shall lead to more creative solutions and improved product quality [Data: Reports (16, 17, 18, 19, 20, +more)]. By integrating AI with existing enterprise resource planning (ERP) systems, SAP can streamline workflows and enhance collaboration, leading to faster product development cycles and higher quality outcomes [Data: Reports (152, 243, 261, 235, 52, +more)].
#
# ### Conclusion
#
# In summary, SAP can utilize AI to enhance its product development process by implementing proactive quality assurance, automating routine tasks, leveraging data-driven insights, establishing continuous feedback mechanisms, and fostering collaboration. These strategies shall not only accelerate innovation and improve product quality but also reduce costs and time to market, positioning SAP for greater success in a competitive landscape.
# Performing search with query: Considering the growing importance of sustainability, how can SAP leverage its technology and expertise to help its customers achieve their own sustainability goals, creating new revenue streams and strengthening its market position?
# Result for query: Considering the growing importance of sustainability, how can SAP leverage its technology and expertise to help its customers achieve their own sustainability goals, creating new revenue streams and strengthening its market position? is: ## Leveraging Technology for Sustainability
#
# SAP can significantly enhance its market position and create new revenue streams by leveraging its advanced data analytics and cloud solutions to assist customers in achieving their sustainability goals. By providing insights into sustainability performance, SAP enables organizations to track and optimize their resource usage and emissions. This capability is crucial as it allows companies to identify areas for improvement and implement more sustainable practices, ultimately aligning with global sustainability objectives [Data: Reports (152, 243, 272, 261, 235)].
#
# ### Integration of Sustainability Metrics
#
# Integrating sustainability metrics into existing enterprise resource planning (ERP) systems shall enable SAP to streamline customer operations and reduce waste. This integration not only supports sustainability initiatives but also positions SAP as a leader in sustainable business practices. By facilitating better decision-making and enhancing operational efficiency, SAP can help customers achieve cost savings while improving their sustainability outcomes [Data: Reports (140, 189, 319, 85, 122)].
#
# ### Enhancing Corporate Social Responsibility (CSR)
#
# SAP's technology can also enhance Corporate Social Responsibility (CSR) practices among its customers. By providing tools that assist companies in implementing effective CSR strategies, SAP can help clients achieve better stakeholder relationships and financial outcomes. This approach may create new revenue streams for SAP through software and consulting services focused on sustainability [Data: Reports (148, 166, 163)].
#
# ### Sustainable Supply Chain Management
#
# SAP's expertise in supply chain management can be leveraged to promote sustainable sourcing and logistics practices. By offering insights into supply chain sustainability, SAP can assist customers in making informed decisions that align with their sustainability goals. This capability not only helps organizations reduce their environmental impact but also opens up new market opportunities for SAP's solutions [Data: Reports (180, 83, 196, 77, 114)].
#
# ### Innovative Solutions and Partnerships
#
# The development of innovative sustainability reporting tools and applications can enable customers to comply with regulatory requirements and effectively communicate their sustainability efforts to stakeholders. This capability may enhance customer loyalty and attract new clients seeking to improve their sustainability reporting [Data: Reports (140, 189, 235, 261, 243)]. Furthermore, forming strategic partnerships with organizations focused on sustainability can enhance SAP's offerings and expand its market reach, allowing for the co-creation of solutions that address specific environmental challenges [Data: Reports (152, 243, 272, 261, 235)].
#
# ### Conclusion
#
# In summary, SAP has the potential to leverage its technology and expertise to help customers achieve their sustainability goals through advanced analytics, integration of sustainability metrics, enhancement of CSR practices, and sustainable supply chain management. By developing innovative solutions and fostering partnerships, SAP can not only strengthen its market position but also create new revenue streams, positioning itself as a leader in the sustainability technology space [Data: Reports (60, 170, 233, 357, 134)].
# Performing search with query: How can SAP utilize AI to improve its financial forecasting and planning capabilities, enhancing its decision-making processes and improving its overall financial performance?
# Result for query: How can SAP utilize AI to improve its financial forecasting and planning capabilities, enhancing its decision-making processes and improving its overall financial performance? is: ## Enhancing Financial Forecasting and Planning with AI
#
# ...
#
# SAP can significantly improve its internal audit and compliance processes by leveraging artificial intelligence (AI) technologies. The integration of AI-driven analytics and automation can help mitigate potential risks, ensure regulatory compliance, and enhance operational efficiency in several key areas.
#
# ## Proactive Risk Management
#
# AI can be utilized to analyze large volumes of data in real-time, identifying anomalies and patterns that may indicate compliance risks or fraudulent activities. This proactive approach enables SAP to address potential issues before they escalate, ensuring regulatory compliance and enhancing the overall integrity of its operations [Data: Reports (272, 261, 220, 201, 140, +more)]. By continuously monitoring compliance with regulatory requirements, AI-driven analytics can enhance SAP's risk assessment capabilities, allowing for timely interventions and adjustments to compliance strategies [Data: Reports (125, 168, 126)].
#
# Furthermore, AI can provide predictive insights into compliance risks by analyzing historical data and identifying patterns that may indicate future issues. This capability allows SAP to forecast potential compliance risks and develop targeted compliance strategies, ultimately leading to improved governance and reduced exposure to regulatory penalties [Data: Reports (243, 261, 235, 140, 220, +more)].
#
# ## Automation of Audit Processes
#
# The automation of routine audit tasks, such as data analysis and transaction monitoring, is another critical area where AI can enhance operational efficiency. By automating these processes, SAP can reduce the time auditors spend on manual tasks, allowing them to focus on more complex issues. This shift not only improves the thoroughness and timeliness of audits but also mitigates risks associated with human error and oversight [Data: Reports (152, 243, 261, 235, 140, +more)].
#
# AI-driven tools can facilitate continuous auditing, enabling SAP to maintain an ongoing assessment of compliance and operational processes rather than relying solely on periodic audits. This continuous monitoring can lead to quicker identification of compliance gaps and operational inefficiencies, fostering a culture of accountability and proactive risk management [Data: Reports (170, 233, 357, 134, 241)].
#
# ## Streamlining Compliance Reporting
#
# Integrating AI with existing compliance management systems can streamline reporting processes, making it easier for SAP to generate compliance reports and documentation required by regulatory bodies. This efficiency not only saves time but also ensures that SAP remains compliant with evolving regulations [Data: Reports (243, 261, 235, 140, 220, +more)]. AI can assist in maintaining accurate records and generating compliance reports automatically, thus reducing manual effort and the risk of human error [Data: Reports (150, 82, 91, 182, 202)].
#
# Moreover, AI can enhance internal communication and collaboration among audit teams by providing insights and recommendations based on data analysis. This collaborative approach fosters a culture of compliance and accountability within SAP, ensuring that all employees are aligned with regulatory requirements and internal policies [Data: Reports (152, 261, 235, 140, 220, +more)].
#
# ## Conclusion
#
# In conclusion, SAP can leverage AI to enhance its internal audit and compliance processes significantly. By adopting AI-driven analytics for proactive risk management, automating routine audit tasks, and streamlining compliance reporting, SAP shall not only mitigate potential risks and ensure regulatory compliance but also enhance its operational efficiency. This strategic integration of AI technologies will position SAP to respond swiftly to regulatory changes and maintain a robust compliance framework in an increasingly complex regulatory environment.
# Performing search with query: How can SAP utilize AI to improve its product pricing and revenue management strategies, maximizing profitability while simultaneously maintaining customer satisfaction and market competitiveness?
# Result for query: How can SAP utilize AI to improve its product pricing and revenue management strategies, maximizing profitability while simultaneously maintaining customer satisfaction and market competitiveness? is: ## Leveraging AI for Enhanced Pricing and Revenue Management at SAP
#
# SAP can significantly enhance its product pricing and revenue management strategies by leveraging artificial intelligence (AI) in several key areas. The integration of AI-driven analytics and machine learning algorithms will enable SAP to optimize pricing models, forecast customer demand, and maintain competitiveness in the market.
#
# ### Dynamic Pricing Models
#
# AI can facilitate the development of dynamic pricing models that adjust in real-time based on various factors such as demand fluctuations, competitor pricing, and market conditions. By analyzing vast amounts of market data and customer behavior, SAP may implement pricing strategies that maximize revenue opportunities while ensuring that prices remain competitive. This approach not only enhances profitability but also aligns pricing with customer expectations, thereby improving overall satisfaction [Data: Reports (180, 83, 196, 77, 114)].
#
# ### Predictive Analytics for Demand Forecasting
#
# Implementing AI-driven predictive analytics will allow SAP to forecast customer demand more accurately. This capability can lead to better inventory management and pricing strategies that align with anticipated market trends. By ensuring product availability at optimal prices, SAP can enhance customer satisfaction and loyalty, which are crucial for long-term profitability [Data: Reports (125, 168, 126, 128, 120, +more)].
#
# ### Personalized Pricing Strategies
#
# AI can also enable SAP to develop personalized pricing strategies by analyzing individual customer data and preferences. This level of customization allows SAP to tailor pricing models to different customer segments, ensuring that pricing reflects the perceived value for each group. Such personalization can lead to increased customer loyalty and repeat business, ultimately driving profitability [Data: Reports (238, 292, 240, 373, 187)].
#
# ### Competitive Analysis and Market Responsiveness
#
# Utilizing AI for competitive analysis will allow SAP to continuously monitor competitors' pricing and promotional strategies. This intelligence can inform proactive adjustments to SAP's pricing models, ensuring that the company remains competitive without sacrificing profitability. By being responsive to market changes, SAP can maintain its market position and enhance customer satisfaction [Data: Reports (316, 188, 58, 101, 239, +more)].
#
# ### Automation of Revenue Management Processes
#
# AI can facilitate the automation of revenue management processes, reducing manual errors and increasing efficiency. This automation will enable SAP to quickly respond to market changes and optimize pricing strategies without compromising service quality. By streamlining these processes, SAP can focus on strategic initiatives that enhance market competitiveness [Data: Reports (150, 82, 91, 182, 202)].
#
# ### Conclusion
#
# In summary, SAP can utilize AI to improve its product pricing and revenue management strategies by implementing dynamic pricing models, leveraging predictive analytics for demand forecasting, developing personalized pricing strategies, conducting competitive analysis, and automating revenue management processes. These strategies will not only maximize profitability but also ensure that customer satisfaction and market competitiveness are maintained, positioning SAP for sustained success in a dynamic market environment [Data: Reports (180, 83, 196, 77, 114)].
# Performing search with query: How can SAP utilize AI to improve its supply chain resilience, mitigating risks associated with disruptions and geopolitical instability while simultaneously enhancing its overall operational efficiency?
# Result for query: How can SAP utilize AI to improve its supply chain resilience, mitigating risks associated with disruptions and geopolitical instability while simultaneously enhancing its overall operational efficiency? is: # Enhancing Supply Chain Resilience through AI at SAP
#
# SAP can leverage artificial intelligence (AI) to significantly improve its supply chain resilience, particularly in the face of disruptions and geopolitical instability. By implementing AI-driven strategies, SAP may enhance operational efficiency while proactively managing risks. Below are key areas where AI can be effectively utilized:
#
# ## Real-Time Data Analysis and Risk Management
#
# Implementing AI for real-time data analysis allows SAP to swiftly identify and respond to supply chain disruptions. This capability is crucial for adapting to changing market conditions and geopolitical landscapes, ensuring continuity in operations [Data: Reports (261, 243, 272, 220, 201)]. AI can analyze data from various sources, including market trends and geopolitical events, to identify potential risks, enabling SAP to develop contingency plans and adjust operations accordingly [Data: Reports (391, 120, 72)].
#
# ## Predictive Analytics for Enhanced Visibility
#
# AI can enhance supply chain visibility through predictive analytics, which forecasts potential disruptions and geopolitical risks. This proactive approach allows SAP to make timely adjustments in supply chain strategies, ensuring effective responses to unforeseen events [Data: Reports (57, 61, 263, 211, 262)]. By utilizing predictive analytics, SAP can improve demand forecasting accuracy, leading to better inventory management and reducing the risk of stockouts or overstock situations [Data: Reports (391, 120, 72)].
#
# ## Scenario Planning and Simulation
#
# Utilizing AI for scenario planning enables SAP to simulate various disruption scenarios and assess their potential impacts on the supply chain. This strategic foresight allows SAP to prepare for potential challenges, thereby strengthening its supply chain resilience [Data: Reports (238, 292, 240, 373, 187)]. By modeling different scenarios, SAP can develop robust risk management strategies and improve overall operational efficiency [Data: Reports (57, 61, 211, 262, 294)].
#
# ## Automation and Operational Efficiency
#
# AI-driven automation can streamline supply chain processes, reducing manual intervention and increasing efficiency. By automating routine tasks, SAP can minimize errors and improve response times, which is essential for maintaining operational efficiency during disruptions [Data: Reports (197, 276, 71, 254, 294)]. This integration of AI into supply chain operations can lead to significant cost savings and improved service levels [Data: Reports (180, 83, 196, 77, 114)].
#
# ## Collaboration and Communication Enhancement
#
# AI can facilitate better collaboration and communication across SAP's supply chain network. Enhanced collaboration tools powered by AI can improve information sharing among stakeholders, leading to more coordinated efforts in risk mitigation [Data: Reports (140, 243, 261, 220, 201)]. This interconnectedness allows for real-time updates and shared insights, which are crucial for maintaining resilience during geopolitical instability [Data: Reports (60, 170, 233, 357, 134)].
#
# ## Conclusion
#
# In summary, SAP can utilize AI to enhance its supply chain resilience by implementing real-time data analysis, predictive analytics, scenario planning, automation, and improved collaboration. These strategies will not only mitigate risks associated with disruptions and geopolitical instability but also enhance overall operational efficiency, positioning SAP to respond effectively to future challenges. By adopting these AI-driven approaches, SAP shall ensure a more resilient and agile supply chain capable of navigating the complexities of the modern business environment.
# Performing search with query: How can SAP leverage its technology and expertise to help its customers address the challenges of climate change, creating new revenue streams and strengthening its market position?
# Result for query: How can SAP leverage its technology and expertise to help its customers address the challenges of climate change, creating new revenue streams and strengthening its market position? is: ## Leveraging Technology for Climate Change Solutions
#
# SAP can significantly enhance its market position and create new revenue streams by leveraging its advanced technology and expertise to help customers address climate change challenges. The integration of data analytics and cloud computing capabilities allows SAP to provide comprehensive tools that enable organizations to measure, report, and reduce their carbon footprints. By offering solutions that assist businesses in tracking emissions and optimizing resource usage, SAP positions itself as a leader in sustainability solutions, which may lead to subscription-based services and consulting opportunities [Data: Reports (152, 243, 272, 261, 235)].
#
# ### Enhancing Sustainability Practices
#
# SAP's expertise in enterprise resource planning (ERP) can be utilized to integrate sustainability into core business processes. This integration enables customers to optimize their supply chains and resource management with sustainability metrics, which can lead to waste reduction and improved efficiency. Such capabilities are crucial as organizations increasingly seek to meet sustainability targets and comply with regulatory requirements [Data: Reports (125, 168, 126, 128, 120, +more)]. By facilitating the development of sustainable supply chains and responsible sourcing practices, SAP can help clients not only reduce their environmental impact but also identify cost savings and efficiency improvements [Data: Reports (231, 150, 82)].
#
# ### Innovative Solutions and Partnerships
#
# Investing in research and development for innovative technologies, such as artificial intelligence and machine learning, will enable SAP to create predictive models that help customers anticipate climate-related risks and opportunities. This proactive approach can enhance customer loyalty and open new markets for SAP's technology solutions [Data: Reports (238, 292, 244, 187, 240)]. Furthermore, by developing partnerships with organizations focused on climate action, such as NGOs and governmental bodies, SAP can enhance its offerings and credibility in the market. Collaborations can lead to innovative solutions that address climate challenges, thus expanding SAP's market reach and creating additional revenue opportunities [Data: Reports (152, 243, 261, 235, 220)].
#
# ### Industry-Specific Solutions
#
# SAP can also develop industry-specific solutions that cater to the unique challenges faced by sectors heavily impacted by climate change, such as manufacturing, energy, and agriculture. By tailoring its technology to meet the specific needs of these industries, SAP can capture a larger market share and drive revenue growth [Data: Reports (170, 233, 357, 241, 176)]. This strategic positioning not only addresses climate change challenges but also enhances customer loyalty and opens up new business opportunities for SAP's products and services [Data: Reports (239, 316, 188, 58, 101)].
#
# ### Conclusion
#
# In summary, SAP's commitment to sustainability, combined with its technological capabilities, positions it well to assist customers in navigating the complexities of climate change. By providing tools for measuring and managing carbon emissions, integrating sustainability into business processes, fostering partnerships, and developing industry-specific solutions, SAP can create new revenue streams while strengthening its market position in an increasingly environmentally conscious landscape [Data: Reports (57, 61, 211, 276, 71)].

# %%
data_to_save = [
    {
        "user_input": sample.user_input,
        "response": sample.response,
        "reference": sample.reference
    }
    for sample in evaluation_samples
]

with open(TEMP+'/evaluation_dataset_final_after_grag.json', 'w', encoding='utf-8') as f:
    json.dump(data_to_save, f, ensure_ascii=False, indent=4)

# %%
with open(TEMP+'evaluation_dataset_final_after_grag.json', 'r', encoding="utf-8") as f:
    dataset = json.load(f)

evaluation_dataset = EvaluationDataset.from_dict(dataset)

evaluator_llm = LangchainLLMWrapper(llm_sap)
#evaluator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

metrics = [
    FactualCorrectness(llm=evaluator_llm, mode="precision", name="FactualCorrectness_Precision"),
    FactualCorrectness(llm=evaluator_llm, mode="recall", name="FactualCorrectness_Recall"),
    FactualCorrectness(llm=evaluator_llm, mode="f1", name="FactualCorrectness_F1"),
    #Faithfulness(llm=evaluator_llm), 
]
results = evaluate(dataset=evaluation_dataset, metrics=metrics)
df_grag = results.to_pandas()
# Out:
# Evaluating: 100%|██████████| 102/102 [04:58<00:00,  2.93s/it]

# %%
pd.set_option('display.max_colwidth', 2500) # default is 50 / None for unlimited
df_grag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.set_option('display.max_colwidth', 2500) # default is 50 / None for unlimited
#       2 df_grag
#
# NameError: name 'pd' is not defined

# %%
average_metrics_grag = df_grag[['FactualCorrectness_Precision', 'FactualCorrectness_Recall', 'FactualCorrectness_F1']].mean().round(4)
average_metrics_rag = df_rag[['FactualCorrectness_Precision', 'FactualCorrectness_Recall', 'FactualCorrectness_F1']].mean().round(4)

print("Average for each metric (GraphRAG):")
print(average_metrics_grag)
print("Average for each metric (RAG):")
print(average_metrics_rag)
# Out:
# Average for each metric (GraphRAG):
# FactualCorrectness_Precision    0.5085
# FactualCorrectness_Recall       0.5041
# FactualCorrectness_F1           0.4794
# dtype: float64
# Average for each metric (RAG):
# FactualCorrectness_Precision    0.5982
# FactualCorrectness_Recall       0.2232
# FactualCorrectness_F1           0.3176
# dtype: float64
